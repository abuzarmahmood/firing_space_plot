# %%
import numpy as np
import pylab as plt
from glob import glob
import os
from fnmatch import filter
from scipy.stats import zscore, percentileofscore, ttest_ind
import pymc3 as pm
from theano import tensor as tt
from sklearn.impute import SimpleImputer
from tqdm import tqdm

# %%
data_dir = '/media/fastdata/brad_changepoint/raw_data/'

# %%
file_list = glob(os.path.join(data_dir,"*.npy"))
lfp_files = [x for x in file_list if 'rear' not in x]
rear_files = [x for x in file_list if 'rear' in x]

# %%
load_groups = [['cons1','cons2'],['exps1','expl1']]
lfp_groups = [[[x for x in lfp_files if name in x] for name in group] for group in load_groups]
rear_groups = [[[x for x in rear_files if name in x] for name in group] for group in load_groups]
lfp_groups = np.squeeze(np.array(lfp_groups))
rear_groups = np.squeeze(np.array(rear_groups))

# %%
lfp_groups
# Out:
# array([['/media/fastdata/brad_changepoint/raw_data/cons1.npy',
#         '/media/fastdata/brad_changepoint/raw_data/cons2.npy'],
#        ['/media/fastdata/brad_changepoint/raw_data/exps1.npy',
#         '/media/fastdata/brad_changepoint/raw_data/expl1.npy']],
#       dtype='<U51')

# %%
rear_groups
# Out:
# array([['/media/fastdata/brad_changepoint/raw_data/rear_cons1.npy',
#         '/media/fastdata/brad_changepoint/raw_data/rear_cons2.npy'],
#        ['/media/fastdata/brad_changepoint/raw_data/rear_exps1.npy',
#         '/media/fastdata/brad_changepoint/raw_data/rear_expl1.npy']],
#       dtype='<U56')

# %% [markdown]
# # ==== LFP ====

# %%
lfp_dat = np.array([[np.load(x,'r')[:] for x in group] for group in lfp_groups])
zscore_lfp_dat = np.array([[zscore(np.load(x,'r')[:],axis=-1) for x in group] for group in lfp_groups])

# %%
inds = list(np.ndindex(lfp_dat.shape))
fig,ax = plt.subplots(2,2,sharex=True, sharey = 'row')
for this_ind in inds:
    ax[this_ind].imshow(lfp_dat[this_ind],aspect='auto')
    ax[this_ind].set_title(os.path.basename(lfp_groups[this_ind]))
plt.tight_layout()

# %%
inds = list(np.ndindex(lfp_dat.shape))
fig,ax = plt.subplots(2,2,sharex=True, sharey = 'row')
for this_ind in inds:
    ax[this_ind].imshow(zscore_lfp_dat[this_ind],aspect='auto')
    ax[this_ind].set_title(os.path.basename(lfp_groups[this_ind]))
plt.tight_layout()

# %%
inds = list(np.ndindex(lfp_dat.shape))
fig,ax = plt.subplots(2,2,sharex=True, sharey = 'row')
for this_ind in inds:
    ax[this_ind].plot(zscore_lfp_dat[this_ind].T)
    ax[this_ind].set_title(os.path.basename(lfp_groups[this_ind]))
plt.tight_layout()

# %%
lfp_groups.flatten()
# Out:
# array(['/media/fastdata/brad_changepoint/raw_data/cons1.npy',
#        '/media/fastdata/brad_changepoint/raw_data/cons2.npy',
#        '/media/fastdata/brad_changepoint/raw_data/exps1.npy',
#        '/media/fastdata/brad_changepoint/raw_data/expl1.npy'],
#       dtype='<U51')

# %% [markdown]
# ### Con Model

# %%
with pm.Model() as mean_model:
    
    # Define shared "Data" holder to fit same model to different datasets 
    data = pm.Data("data", zscore_lfp_dat[0,0][0])
    # Defining variables with priors
    alpha = data.mean()  # Recall count_data is the
                                   # variable that holds our txt counts
    mu_1 = pm.Normal("mu_1", mu=alpha, sigma = 1)
    mu_2 = pm.Normal("mu_2", mu=alpha, sigma = 1)
    sigma = pm.HalfCauchy('sig', 1)

    idx = np.arange(np.array(mean_model["data"].get_value()).shape[-1])
    
    # Uniform prior
    tau_latent = pm.Uniform('tau_latent', 0, 1)
    
    tau = pm.Deterministic('tau', idx.min() + (idx.max() - idx.min()) * tau_latent)
    
    
    # Using sigmoid rather than switch is supposed to be better
    # for sampler
    weight = tt.nnet.sigmoid(2 * (idx - tau))
    mu_ = (1 - weight) * mu_1 + weight * mu_2

    observation = pm.Normal("obs", mu=mu_, sigma = sigma, observed=data)

pm.model_to_graphviz(mean_model)

# %%
with pm.Model() as full_model:
    
    # Define shared "Data" holder to fit same model to different datasets 
    data = pm.Data("data", zscore_lfp_dat[0,0][0])
    # Defining variables with priors
    alpha = data.mean()  # Recall count_data is the
                                   # variable that holds our txt counts
    mu_1 = pm.Normal("mu_1", mu=alpha, sigma = 1)
    mu_2 = pm.Normal("mu_2", mu=alpha, sigma = 1)
    sigma_1 = pm.HalfCauchy('sig1', 1)
    sigma_2 = pm.HalfCauchy('sig2', 1)

    idx = np.arange(np.array(mean_model["data"].get_value()).shape[-1])
    
    # Uniform prior
    tau_latent = pm.Uniform('tau_latent', 0, 1)
    
    tau = pm.Deterministic('tau', idx.min() + (idx.max() - idx.min()) * tau_latent)
    
    
    # Using sigmoid rather than switch is supposed to be better
    # for sampler
    weight = tt.nnet.sigmoid(2 * (idx - tau))
    mu_ = (1 - weight) * mu_1 + weight * mu_2
    sigma_ = (1 - weight) * sigma_1 + weight * sigma_2

    observation = pm.Normal("obs", mu=mu_, sigma = sigma_, observed=data)

pm.model_to_graphviz(full_model)

# %%
with pm.Model() as full_model3:
    
    # Define shared "Data" holder to fit same model to different datasets 
    data = pm.Data("data", zscore_lfp_dat[0,0][0])
    # Defining variables with priors
    alpha = data.mean()  # Recall count_data is the
                                   # variable that holds our txt counts
    mu_1 = pm.Normal("mu_1", mu=alpha, sigma = 1, testval = 0)
    mu_2 = pm.Normal("mu_2", mu=alpha, sigma = 1, testval = 0)
    mu_3 = pm.Normal("mu_3", mu=alpha, sigma = 1, testval = 0)
    sigma1 = pm.HalfCauchy('sig_1', 1, testval = 1)
    sigma2 = pm.HalfCauchy('sig_2', 1, testval = 1)
    sigma3 = pm.HalfCauchy('sig_3', 1, testval = 1)

    idx = np.arange(np.array(mean_model["data"].get_value()).shape[-1])
    
    # Uniform prior
    tau_latent = pm.Uniform('tau_latent', 0, 1, shape = 2)
    tau_sort = pm.Deterministic('tau_sort', tau_latent.sort())
    
    tau = pm.Deterministic('tau', idx.min() + (idx.max() - idx.min()) * tau_sort)
    
    
    # Using sigmoid rather than switch is supposed to be better
    # for sampler
    weight1 = tt.nnet.sigmoid(2 * (idx - tau[0]))
    weight2 = tt.nnet.sigmoid(2 * (idx - tau[1]))
    mu_ = (1 - weight1) * mu_1 + (weight1*(1-weight2)) * mu_2 + weight2 * mu_3
    sig_ = (1 - weight1) * sigma1 + (weight1*(1-weight2)) * sigma2 + weight2 * sigma3

    observation = pm.Normal("obs", mu=mu_, sigma = sig_, observed=data)

pm.model_to_graphviz(full_model3)

# %%
fig, ax = plt.subplots(1,2, figsize = (10,3))
for this_ax,dat in zip(ax,zscore_lfp_dat[0]):
    this_ax.imshow(dat,aspect='auto')

# %%
# Generate one trace for each dataset
con1_traces = []
for data_vals in zscore_lfp_dat[0,0]:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        con1_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
        
# Generate one trace for each dataset
con2_traces = []
for data_vals in zscore_lfp_dat[0,1]:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        con2_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2079.32draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2027.74draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2133.48draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1911.33draws/s]
# The acceptance probability does not match the target. It is 0.5974752804779511, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.4968283273212028, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.6867592734828252, but should be close to 0.8. Try to increase the number of tuning steps.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1826.86draws/s]
# The acceptance probability does not match the target. It is 0.7053471555112701, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1891.67draws/s]
# The acceptance probability does not match the target. It is 0.70476697743698, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2405.62draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2322.63draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2221.77draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2060.85draws/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
con1_tau_array = np.array([this_trace["tau"] for this_trace in con1_traces])
con2_tau_array = np.array([this_trace["tau"] for this_trace in con2_traces])

fig, ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].hist(con1_tau_array.T, np.arange(20), stacked = 'true');
ax[0,1].hist(con1_tau_array.flatten(), np.arange(20), stacked = 'true');
ax[1,0].hist(con2_tau_array.T, np.arange(20), stacked = 'true');
ax[1,1].hist(con2_tau_array.flatten(), np.arange(20), stacked = 'true');

ax[0,0].set_ylabel('Con1');
ax[1,0].set_ylabel('Con2');

# %%
con1_tau_hists = np.array([np.histogram(x, np.arange(20))[0] for x in con1_tau_array])
con2_tau_hists = np.array([np.histogram(x, np.arange(20))[0] for x in con2_tau_array])

# %%
fig,ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].imshow(con1_tau_hists,aspect='auto');
ax[1,0].imshow(con2_tau_hists,aspect='auto');
ax[0,1].plot(con1_tau_hists.T);
ax[1,1].plot(con2_tau_hists.T);

# %% [markdown]
# ### Exp Model

# %%
fig, ax = plt.subplots(1,2, figsize = (10,3))
for this_ax,dat in zip(ax,zscore_lfp_dat[1]):
    this_ax.imshow(dat,aspect='auto')

# %%
rows = zscore_lfp_dat[1,0].shape[0]
fig, ax = plt.subplots(rows, 3, figsize = (5,10))
for num in range(rows):
    ax[num,0].plot(zscore_lfp_dat[1,0][num])
    ax[num,0].plot(zscore_lfp_dat[1,1][num])
    ax[num,1].plot(zscore_lfp_dat[1,1][num] - zscore_lfp_dat[1,0][num])
    ax[num,2].plot(np.abs(zscore_lfp_dat[1,1][num] - zscore_lfp_dat[1,0][num]))

# %%
# Generate one trace for each dataset
exp1_traces = []
for data_vals in zscore_lfp_dat[1,0]:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        exp1_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
        
# Generate one trace for each dataset
exp2_traces = []
for data_vals in zscore_lfp_dat[1,1]:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        exp2_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2008.06draws/s]
# The acceptance probability does not match the target. It is 0.6344906543467312, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.6556305095936011, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2001.01draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2110.39draws/s]
# The acceptance probability does not match the target. It is 0.6955778141843965, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.6301644193259498, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.6338073307852051, but should be close to 0.8. Try to increase the number of tuning steps.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2847.07draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2808.21draws/s]
# The acceptance probability does not match the target. It is 0.8786711431349149, but should be close to 0.8. Try to increase the number of tuning steps.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2088.90draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2367.37draws/s]
# The acceptance probability does not match the target. It is 0.9113036989046243, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2056.75draws/s]
# The acceptance probability does not match the target. It is 0.7214910099351153, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2600.05draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2198.70draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2279.94draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2327.90draws/s]
# The acceptance probability does not match the target. It is 0.6447594761608884, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.5651700411290372, but should be close to 0.8. Try to increase the number of tuning steps.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1856.27draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2196.81draws/s]
# The acceptance probability does not match the target. It is 0.895829038843279, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.7212147577518101, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.5285988663699362, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %%
exp1_tau_array = np.array([this_trace["tau"] for this_trace in exp1_traces])
exp2_tau_array = np.array([this_trace["tau"] for this_trace in exp2_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].hist(exp1_tau_array.T, bins, stacked = 'true');
ax[0,1].hist(exp1_tau_array.flatten(), bins, stacked = 'true');
ax[1,0].hist(exp2_tau_array.T, bins, stacked = 'true');
ax[1,1].hist(exp2_tau_array.flatten(), bins, stacked = 'true');

ax[0,0].set_ylabel('Con');
ax[1,0].set_ylabel('Exp');

# %%
exp1_tau_hists = np.array([np.histogram(x, bins)[0] for x in exp1_tau_array])
exp2_tau_hists = np.array([np.histogram(x, bins)[0] for x in exp2_tau_array])

# %%
fig,ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].imshow(exp1_tau_hists,aspect='auto');
ax[1,0].imshow(exp2_tau_hists,aspect='auto');
ax[0,1].plot(exp1_tau_hists.T);
ax[1,1].plot(exp2_tau_hists.T);

# %% [markdown]
# ### ==== Diff Changes ====

# %%
exp_diff_lfp = np.diff(zscore_lfp_dat[1], axis=0)[0]
con_diff_lfp = np.diff(zscore_lfp_dat[0], axis=0)[0]

# %%
# Generate one trace for each dataset
exp_diff_traces = []
for data_vals in exp_diff_lfp:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        exp_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Generate one trace for each dataset
con_diff_traces = []
for data_vals in con_diff_lfp:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        con_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 47/4000 [00:00<00:08, 469.67draws/s]
# Sampling 4 chains, 0 divergences:   5%|▌         | 206/4000 [00:00<00:06, 595.48draws/s]
# Sampling 4 chains, 0 divergences:  10%|█         | 414/4000 [00:00<00:04, 757.39draws/s]
# Sampling 4 chains, 0 divergences:  16%|█▌        | 649/4000 [00:00<00:03, 950.67draws/s]
# Sampling 4 chains, 0 divergences:  22%|██▏       | 894/4000 [00:00<00:02, 1163.89draws/s]
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1071/4000 [00:00<00:02, 1295.52draws/s]
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1319/4000 [00:00<00:01, 1512.06draws/s]
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1537/4000 [00:00<00:01, 1664.97draws/s]
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1772/4000 [00:00<00:01, 1823.57draws/s]
# Sampling 4 chains, 0 divergences:  51%|█████     | 2038/4000 [00:01<00:00, 2013.30draws/s]
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2291/4000 [00:01<00:00, 2144.70draws/s]
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2529/4000 [00:01<00:00, 2208.30draws/s]
# Sampling 4 chains, 0 divergences:  70%|██████▉   | 2793/4000 [00:01<00:00, 2322.22draws/s]
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3038/4000 [00:01<00:00, 2322.29draws/s]
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3292/4000 [00:01<00:00, 2382.61draws/s]
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3537/4000 [00:01<00:00, 2095.04draws/s]
# Sampling 4 chains, 0 divergences:  94%|█████████▍| 3758/4000 [00:01<00:00, 2097.37draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1946.74draws/s]
# The acceptance probability does not match the target. It is 0.686238071019429, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.7206720900025484, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   2%|▏         | 95/4000 [00:00<00:04, 949.06draws/s]
# Sampling 4 chains, 0 divergences:   9%|▉         | 357/4000 [00:00<00:03, 1173.42draws/s]
# Sampling 4 chains, 0 divergences:  15%|█▍        | 593/4000 [00:00<00:02, 1380.87draws/s]
# Sampling 4 chains, 0 divergences:  21%|██        | 839/4000 [00:00<00:01, 1589.30draws/s]
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1086/4000 [00:00<00:01, 1779.34draws/s]
# Sampling 4 chains, 0 divergences:  34%|███▍      | 1367/4000 [00:00<00:01, 1998.47draws/s]
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1682/4000 [00:00<00:01, 2243.74draws/s]
# Sampling 4 chains, 0 divergences:  50%|█████     | 2013/4000 [00:00<00:00, 2482.75draws/s]
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2299/4000 [00:00<00:00, 2583.09draws/s]
# Sampling 4 chains, 0 divergences:  65%|██████▌   | 2604/4000 [00:01<00:00, 2706.92draws/s]
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2927/4000 [00:01<00:00, 2844.41draws/s]
# Sampling 4 chains, 0 divergences:  81%|████████  | 3238/4000 [00:01<00:00, 2604.53draws/s]
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3511/4000 [00:01<00:00, 2526.15draws/s]
# Sampling 4 chains, 0 divergences:  94%|█████████▍| 3773/4000 [00:01<00:00, 1675.90draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1958.51draws/s]
# The acceptance probability does not match the target. It is 0.8922050945720862, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9012501219808937, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   2%|▏         | 64/4000 [00:00<00:06, 638.07draws/s]
# Sampling 4 chains, 0 divergences:   7%|▋         | 281/4000 [00:00<00:04, 809.33draws/s]
# Sampling 4 chains, 0 divergences:  13%|█▎        | 538/4000 [00:00<00:03, 1018.61draws/s]
# Sampling 4 chains, 0 divergences:  20%|██        | 819/4000 [00:00<00:02, 1259.00draws/s]
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1108/4000 [00:00<00:01, 1515.49draws/s]
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1319/4000 [00:00<00:01, 1649.96draws/s]
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1568/4000 [00:00<00:01, 1835.14draws/s]
# Sampling 4 chains, 0 divergences:  46%|████▌     | 1825/4000 [00:00<00:01, 2006.59draws/s]
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2091/4000 [00:00<00:00, 2162.29draws/s]
# Sampling 4 chains, 0 divergences:  59%|█████▉    | 2374/4000 [00:01<00:00, 2326.01draws/s]
# Sampling 4 chains, 0 divergences:  66%|██████▋   | 2651/4000 [00:01<00:00, 2441.22draws/s]
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2912/4000 [00:01<00:00, 2465.73draws/s]
# Sampling 4 chains, 0 divergences:  80%|███████▉  | 3187/4000 [00:01<00:00, 2544.54draws/s]
# Sampling 4 chains, 0 divergences:  86%|████████▋ | 3451/4000 [00:01<00:00, 2539.91draws/s]
# Sampling 4 chains, 0 divergences:  93%|█████████▎| 3712/4000 [00:01<00:00, 2307.55draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2114.53draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 33/4000 [00:00<00:12, 328.24draws/s]
# Sampling 4 chains, 0 divergences:   6%|▌         | 220/4000 [00:00<00:08, 436.05draws/s]
# Sampling 4 chains, 0 divergences:  12%|█▏        | 475/4000 [00:00<00:06, 580.31draws/s]
# Sampling 4 chains, 0 divergences:  17%|█▋        | 687/4000 [00:00<00:04, 741.77draws/s]
# Sampling 4 chains, 0 divergences:  23%|██▎       | 908/4000 [00:00<00:03, 926.15draws/s]
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1103/4000 [00:00<00:02, 1099.27draws/s]
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1315/4000 [00:00<00:02, 1284.81draws/s]
# Sampling 4 chains, 0 divergences:  39%|███▊      | 1541/4000 [00:00<00:01, 1475.49draws/s]
# Sampling 4 chains, 0 divergences:  44%|████▎     | 1746/4000 [00:00<00:01, 1607.09draws/s]
# Sampling 4 chains, 0 divergences:  49%|████▉     | 1969/4000 [00:01<00:01, 1753.07draws/s]
# Sampling 4 chains, 0 divergences:  55%|█████▍    | 2188/4000 [00:01<00:00, 1862.12draws/s]
# Sampling 4 chains, 0 divergences:  60%|██████    | 2401/4000 [00:01<00:00, 1934.79draws/s]
# Sampling 4 chains, 0 divergences:  66%|██████▌   | 2627/4000 [00:01<00:00, 2020.14draws/s]
# Sampling 4 chains, 0 divergences:  71%|███████   | 2846/4000 [00:01<00:00, 2067.20draws/s]
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3071/4000 [00:01<00:00, 2113.60draws/s]
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3320/4000 [00:01<00:00, 2213.16draws/s]
# Sampling 4 chains, 0 divergences:  89%|████████▉ | 3554/4000 [00:01<00:00, 2248.38draws/s]
# Sampling 4 chains, 0 divergences:  95%|█████████▍| 3784/4000 [00:01<00:00, 1996.47draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1797.57draws/s]
# The acceptance probability does not match the target. It is 0.6671699699559589, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   5%|▌         | 210/4000 [00:00<00:01, 2080.25draws/s]
# Sampling 4 chains, 0 divergences:  12%|█▏        | 488/4000 [00:00<00:01, 2248.57draws/s]
# Sampling 4 chains, 0 divergences:  20%|██        | 817/4000 [00:00<00:01, 2484.17draws/s]
# Sampling 4 chains, 0 divergences:  29%|██▉       | 1164/4000 [00:00<00:01, 2713.99draws/s]
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1499/4000 [00:00<00:00, 2875.70draws/s]
# Sampling 4 chains, 0 divergences:  46%|████▌     | 1833/4000 [00:00<00:00, 2999.21draws/s]
# Sampling 4 chains, 0 divergences:  55%|█████▍    | 2195/4000 [00:00<00:00, 3160.75draws/s]
# Sampling 4 chains, 0 divergences:  65%|██████▌   | 2612/4000 [00:00<00:00, 3406.31draws/s]
# Sampling 4 chains, 0 divergences:  75%|███████▌  | 3006/4000 [00:00<00:00, 3550.28draws/s]
# Sampling 4 chains, 0 divergences:  84%|████████▍ | 3363/4000 [00:01<00:00, 3452.29draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 3019.07draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 25/4000 [00:00<00:15, 248.48draws/s]
# Sampling 4 chains, 0 divergences:   5%|▍         | 184/4000 [00:00<00:11, 332.44draws/s]
# Sampling 4 chains, 0 divergences:  10%|▉         | 386/4000 [00:00<00:08, 443.52draws/s]
# Sampling 4 chains, 0 divergences:  14%|█▍        | 574/4000 [00:00<00:05, 575.29draws/s]
# Sampling 4 chains, 0 divergences:  18%|█▊        | 723/4000 [00:00<00:04, 704.07draws/s]
# Sampling 4 chains, 0 divergences:  22%|██▏       | 874/4000 [00:00<00:03, 837.34draws/s]
# Sampling 4 chains, 0 divergences:  26%|██▋       | 1052/4000 [00:00<00:02, 993.76draws/s]
# Sampling 4 chains, 0 divergences:  30%|███       | 1205/4000 [00:00<00:02, 1110.11draws/s]
# Sampling 4 chains, 0 divergences:  35%|███▍      | 1398/4000 [00:00<00:02, 1271.42draws/s]
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1578/4000 [00:01<00:01, 1391.80draws/s]
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1751/4000 [00:01<00:01, 1476.74draws/s]
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1920/4000 [00:01<00:01, 1520.01draws/s]
# Sampling 4 chains, 0 divergences:  53%|█████▎    | 2120/4000 [00:01<00:01, 1636.53draws/s]
# Sampling 4 chains, 0 divergences:  58%|█████▊    | 2304/4000 [00:01<00:01, 1691.04draws/s]
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2483/4000 [00:01<00:00, 1717.84draws/s]
# Sampling 4 chains, 0 divergences:  67%|██████▋   | 2665/4000 [00:01<00:00, 1746.25draws/s]
# Sampling 4 chains, 0 divergences:  72%|███████▏  | 2862/4000 [00:01<00:00, 1804.35draws/s]
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3047/4000 [00:01<00:00, 1810.76draws/s]
# Sampling 4 chains, 0 divergences:  81%|████████▏ | 3254/4000 [00:01<00:00, 1881.15draws/s]
# Sampling 4 chains, 0 divergences:  86%|████████▌ | 3445/4000 [00:02<00:00, 1887.03draws/s]
# Sampling 4 chains, 0 divergences:  91%|█████████ | 3636/4000 [00:02<00:00, 1863.64draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1599.74draws/s]
# The acceptance probability does not match the target. It is 0.5343179757734284, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 46/4000 [00:00<00:08, 459.70draws/s]
# Sampling 4 chains, 0 divergences:   6%|▌         | 245/4000 [00:00<00:06, 596.90draws/s]
# Sampling 4 chains, 0 divergences:  13%|█▎        | 507/4000 [00:00<00:04, 776.27draws/s]
# Sampling 4 chains, 0 divergences:  18%|█▊        | 722/4000 [00:00<00:03, 959.76draws/s]
# Sampling 4 chains, 0 divergences:  22%|██▎       | 900/4000 [00:00<00:02, 1112.46draws/s]
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1108/4000 [00:00<00:02, 1292.74draws/s]
# Sampling 4 chains, 0 divergences:  34%|███▎      | 1342/4000 [00:00<00:01, 1493.16draws/s]
# Sampling 4 chains, 0 divergences:  40%|███▉      | 1584/4000 [00:00<00:01, 1686.86draws/s]
# Sampling 4 chains, 0 divergences:  46%|████▌     | 1836/4000 [00:00<00:01, 1870.88draws/s]
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2075/4000 [00:01<00:00, 2001.00draws/s]
# Sampling 4 chains, 0 divergences:  58%|█████▊    | 2325/4000 [00:01<00:00, 2127.58draws/s]
# Sampling 4 chains, 0 divergences:  64%|██████▍   | 2569/4000 [00:01<00:00, 2211.63draws/s]
# Sampling 4 chains, 0 divergences:  70%|███████   | 2815/4000 [00:01<00:00, 2279.54draws/s]
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3077/4000 [00:01<00:00, 2370.45draws/s]
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3323/4000 [00:01<00:00, 2360.08draws/s]
# Sampling 4 chains, 0 divergences:  90%|████████▉ | 3595/4000 [00:01<00:00, 2457.21draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1992.69draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 48/4000 [00:00<00:08, 478.13draws/s]
# Sampling 4 chains, 0 divergences:   5%|▌         | 219/4000 [00:00<00:06, 609.46draws/s]
# Sampling 4 chains, 0 divergences:  12%|█▏        | 462/4000 [00:00<00:04, 785.94draws/s]
# Sampling 4 chains, 0 divergences:  17%|█▋        | 683/4000 [00:00<00:03, 974.07draws/s]
# Sampling 4 chains, 0 divergences:  22%|██▏       | 864/4000 [00:00<00:02, 1130.35draws/s]
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1065/4000 [00:00<00:02, 1300.50draws/s]
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1275/4000 [00:00<00:01, 1467.46draws/s]
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1463/4000 [00:00<00:01, 1568.38draws/s]
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1661/4000 [00:00<00:01, 1672.42draws/s]
# Sampling 4 chains, 0 divergences:  46%|████▋     | 1858/4000 [00:01<00:01, 1750.18draws/s]
# Sampling 4 chains, 0 divergences:  51%|█████▏    | 2054/4000 [00:01<00:01, 1807.83draws/s]
# Sampling 4 chains, 0 divergences:  56%|█████▌    | 2246/4000 [00:01<00:00, 1839.01draws/s]
# Sampling 4 chains, 0 divergences:  61%|██████    | 2438/4000 [00:01<00:00, 1848.88draws/s]
# Sampling 4 chains, 0 divergences:  66%|██████▌   | 2631/4000 [00:01<00:00, 1869.44draws/s]
# Sampling 4 chains, 0 divergences:  71%|███████   | 2822/4000 [00:01<00:00, 1855.61draws/s]
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3034/4000 [00:01<00:00, 1926.66draws/s]
# Sampling 4 chains, 0 divergences:  81%|████████  | 3240/4000 [00:01<00:00, 1960.85draws/s]
# Sampling 4 chains, 0 divergences:  86%|████████▋ | 3454/4000 [00:01<00:00, 2010.70draws/s]
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3672/4000 [00:01<00:00, 2056.17draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1785.79draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   3%|▎         | 109/4000 [00:00<00:03, 1085.07draws/s]
# Sampling 4 chains, 0 divergences:   8%|▊         | 302/4000 [00:00<00:02, 1248.93draws/s]
# Sampling 4 chains, 0 divergences:  12%|█▏        | 488/4000 [00:00<00:02, 1383.89draws/s]
# Sampling 4 chains, 0 divergences:  17%|█▋        | 688/4000 [00:00<00:02, 1524.61draws/s]
# Sampling 4 chains, 0 divergences:  22%|██▏       | 866/4000 [00:00<00:01, 1592.47draws/s]
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1062/4000 [00:00<00:01, 1683.95draws/s]
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1269/4000 [00:00<00:01, 1783.08draws/s]
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1492/4000 [00:00<00:01, 1895.64draws/s]
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1683/4000 [00:00<00:01, 1857.89draws/s]
# Sampling 4 chains, 0 divergences:  47%|████▋     | 1884/4000 [00:01<00:01, 1898.40draws/s]
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2092/4000 [00:01<00:00, 1948.82draws/s]
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2295/4000 [00:01<00:00, 1967.87draws/s]
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2504/4000 [00:01<00:00, 2000.98draws/s]
# Sampling 4 chains, 0 divergences:  68%|██████▊   | 2723/4000 [00:01<00:00, 2053.30draws/s]
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2936/4000 [00:01<00:00, 2073.81draws/s]
# Sampling 4 chains, 0 divergences:  79%|███████▊  | 3144/4000 [00:01<00:00, 2045.53draws/s]
# Sampling 4 chains, 0 divergences:  84%|████████▍ | 3363/4000 [00:01<00:00, 2086.66draws/s]
# Sampling 4 chains, 0 divergences:  89%|████████▉ | 3573/4000 [00:01<00:00, 2075.51draws/s]
# Sampling 4 chains, 0 divergences:  95%|█████████▍| 3781/4000 [00:01<00:00, 2059.31draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1832.67draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 25/4000 [00:00<00:15, 249.19draws/s]
# Sampling 4 chains, 0 divergences:   5%|▍         | 190/4000 [00:00<00:11, 334.29draws/s]
# Sampling 4 chains, 0 divergences:  11%|█         | 439/4000 [00:00<00:07, 451.54draws/s]
# Sampling 4 chains, 0 divergences:  17%|█▋        | 678/4000 [00:00<00:05, 596.67draws/s]
# Sampling 4 chains, 0 divergences:  23%|██▎       | 905/4000 [00:00<00:04, 766.04draws/s]
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1118/4000 [00:00<00:03, 947.74draws/s]
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1332/4000 [00:00<00:02, 1137.48draws/s]
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1573/4000 [00:00<00:01, 1351.35draws/s]
# Sampling 4 chains, 0 divergences:  45%|████▍     | 1794/4000 [00:00<00:01, 1529.30draws/s]
# Sampling 4 chains, 0 divergences:  51%|█████     | 2028/4000 [00:01<00:01, 1704.84draws/s]
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2267/4000 [00:01<00:00, 1861.90draws/s]
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2507/4000 [00:01<00:00, 1994.64draws/s]
# Sampling 4 chains, 0 divergences:  69%|██████▊   | 2748/4000 [00:01<00:00, 2101.88draws/s]
# Sampling 4 chains, 0 divergences:  75%|███████▍  | 2993/4000 [00:01<00:00, 2195.12draws/s]
# Sampling 4 chains, 0 divergences:  81%|████████  | 3229/4000 [00:01<00:00, 2140.52draws/s]
# Sampling 4 chains, 0 divergences:  87%|████████▋ | 3467/4000 [00:01<00:00, 2203.41draws/s]
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3697/4000 [00:01<00:00, 2222.29draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2030.71draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   2%|▏         | 60/4000 [00:00<00:06, 594.52draws/s]
# Sampling 4 chains, 0 divergences:   7%|▋         | 272/4000 [00:00<00:04, 758.02draws/s]
# Sampling 4 chains, 0 divergences:  12%|█▏        | 484/4000 [00:00<00:03, 938.70draws/s]
# Sampling 4 chains, 0 divergences:  17%|█▋        | 679/4000 [00:00<00:02, 1111.61draws/s]
# Sampling 4 chains, 0 divergences:  22%|██▏       | 884/4000 [00:00<00:02, 1287.01draws/s]
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1095/4000 [00:00<00:01, 1456.00draws/s]
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1318/4000 [00:00<00:01, 1625.07draws/s]
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1514/4000 [00:00<00:01, 1710.92draws/s]
# Sampling 4 chains, 0 divergences:  43%|████▎     | 1737/4000 [00:00<00:01, 1836.43draws/s]
# Sampling 4 chains, 0 divergences:  49%|████▉     | 1971/4000 [00:01<00:01, 1962.29draws/s]
# Sampling 4 chains, 0 divergences:  55%|█████▍    | 2182/4000 [00:01<00:00, 1975.75draws/s]
# Sampling 4 chains, 0 divergences:  60%|██████    | 2416/4000 [00:01<00:00, 2071.15draws/s]
# Sampling 4 chains, 0 divergences:  67%|██████▋   | 2665/4000 [00:01<00:00, 2180.62draws/s]
# Sampling 4 chains, 0 divergences:  72%|███████▏  | 2891/4000 [00:01<00:00, 2170.21draws/s]
# Sampling 4 chains, 0 divergences:  78%|███████▊  | 3114/4000 [00:01<00:00, 2144.71draws/s]
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3333/4000 [00:01<00:00, 2116.85draws/s]
# Sampling 4 chains, 0 divergences:  89%|████████▊ | 3549/4000 [00:01<00:00, 2128.53draws/s]
# Sampling 4 chains, 0 divergences:  94%|█████████▍| 3764/4000 [00:01<00:00, 2080.43draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1814.19draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 23/4000 [00:00<00:17, 227.65draws/s]
# Sampling 4 chains, 0 divergences:   4%|▍         | 168/4000 [00:00<00:12, 304.54draws/s]
# Sampling 4 chains, 0 divergences:   9%|▉         | 372/4000 [00:00<00:08, 408.86draws/s]
# Sampling 4 chains, 0 divergences:  15%|█▍        | 597/4000 [00:00<00:06, 541.78draws/s]
# Sampling 4 chains, 0 divergences:  20%|██        | 800/4000 [00:00<00:04, 693.77draws/s]
# Sampling 4 chains, 0 divergences:  26%|██▌       | 1039/4000 [00:00<00:03, 881.01draws/s]
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1271/4000 [00:00<00:02, 1082.02draws/s]
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1489/4000 [00:00<00:01, 1274.41draws/s]
# Sampling 4 chains, 0 divergences:  43%|████▎     | 1715/4000 [00:00<00:01, 1465.09draws/s]
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1924/4000 [00:01<00:01, 1599.63draws/s]
# Sampling 4 chains, 0 divergences:  54%|█████▍    | 2152/4000 [00:01<00:01, 1755.65draws/s]
# Sampling 4 chains, 0 divergences:  59%|█████▉    | 2370/4000 [00:01<00:00, 1863.45draws/s]
# Sampling 4 chains, 0 divergences:  65%|██████▍   | 2585/4000 [00:01<00:00, 1938.32draws/s]
# Sampling 4 chains, 0 divergences:  70%|███████   | 2800/4000 [00:01<00:00, 1968.70draws/s]
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3022/4000 [00:01<00:00, 2036.79draws/s]
# Sampling 4 chains, 0 divergences:  81%|████████  | 3237/4000 [00:01<00:00, 2025.59draws/s]
# Sampling 4 chains, 0 divergences:  86%|████████▌ | 3448/4000 [00:01<00:00, 1998.45draws/s]
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3667/4000 [00:01<00:00, 2051.08draws/s]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1796.62draws/s]

# %%
exp_diff_tau_array = np.array([this_trace["tau"] for this_trace in exp_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].hist(exp_diff_tau_array.T, bins, stacked = 'true');
ax[1].hist(exp_diff_tau_array.flatten(), bins, stacked = 'true');

#ax[0,0].set_ylabel('Con');
#ax[1,0].set_ylabel('Exp');

# %%
exp_diff_tau_hists = np.array([np.histogram(x, bins)[0] for x in exp_diff_tau_array])
fig,ax = plt.subplots(2,1, figsize = (5,5))
ax[0].imshow(exp_diff_tau_hists,aspect='auto');
ax[1].plot(exp_diff_tau_hists.T);

# %%
con_diff_tau_array = np.array([this_trace["tau"] for this_trace in con_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].hist(con_diff_tau_array.T, bins, stacked = 'true');
ax[1].hist(con_diff_tau_array.flatten(), bins, stacked = 'true');

#ax[0,0].set_ylabel('Con');
#ax[1,0].set_ylabel('Exp');

# %%
con_diff_tau_hists = np.array([np.histogram(x, bins)[0] for x in con_diff_tau_array])
fig,ax = plt.subplots(2,1, figsize = (5,5))
ax[0].imshow(con_diff_tau_hists,aspect='auto');
ax[1].plot(con_diff_tau_hists.T);

# %% [markdown]
# ### ===== Comparison =====

# %%
fig,ax = plt.subplots(2,2, figsize = (10,5), sharey = 'row')
ax[0,0].plot(con_diff_tau_hists.T);
ax[0,1].plot(exp_diff_tau_hists.T);
ax[1,0].hist(con_diff_tau_array.T, bins, stacked = 'true');
ax[1,1].hist(exp_diff_tau_array.T, bins, stacked = 'true');
ax[0,0].set_title('Control');
ax[0,1].set_title('Experimental');

# %% [markdown]
# # Repeat above with shuffled data

# %%
shuffle_num = 50
con_shuffle_dat = np.array(\
                           [[np.random.permutation(data_vals) \
                             for data_vals in con_diff_lfp] for i in range(shuffle_num)])
exp_shuffle_dat = np.array(\
                           [[np.random.permutation(data_vals) \
                             for data_vals in exp_diff_lfp] for i in range(shuffle_num)])

# %%
con_inds = np.array(list(np.ndindex(con_shuffle_dat.shape[:-1])))
exp_inds = np.array(list(np.ndindex(exp_shuffle_dat.shape[:-1])))

# %%
# Generate one trace for each dataset
exp_shuffle_diff_traces = []
for this_ind in tqdm(exp_inds):
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": exp_shuffle_dat[tuple(this_ind)]})
        exp_shuffle_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
        
# Generate one trace for each dataset
con_shuffle_diff_traces = []
for this_ind in tqdm(con_inds):
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": con_shuffle_dat[tuple(this_ind)]})
        con_shuffle_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Out:
#   0%|          | 0/350 [00:00<?, ?it/s]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|▏         | 57/4000 [00:00<00:06, 569.41draws/s]
#
# Sampling 4 chains, 0 divergences:   5%|▌         | 210/4000 [00:00<00:05, 701.09draws/s]
#
# Sampling 4 chains, 0 divergences:  11%|█         | 426/4000 [00:00<00:04, 879.13draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▌        | 636/4000 [00:00<00:03, 1064.39draws/s]
#
# Sampling 4 chains, 0 divergences:  23%|██▎       | 901/4000 [00:00<00:02, 1296.87draws/s]
#
# Sampling 4 chains, 0 divergences:  29%|██▊       | 1143/4000 [00:00<00:01, 1505.76draws/s]
#
# Sampling 4 chains, 0 divergences:  35%|███▌      | 1411/4000 [00:00<00:01, 1733.19draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1689/4000 [00:00<00:01, 1951.01draws/s]
#
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1937/4000 [00:00<00:00, 2083.77draws/s]
#
# Sampling 4 chains, 0 divergences:  55%|█████▌    | 2202/4000 [00:01<00:00, 2226.00draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2486/4000 [00:01<00:00, 2380.00draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▉   | 2778/4000 [00:01<00:00, 2519.53draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3046/4000 [00:01<00:00, 2544.89draws/s]
#
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3334/4000 [00:01<00:00, 2635.62draws/s]
#
# Sampling 4 chains, 0 divergences:  90%|█████████ | 3613/4000 [00:01<00:00, 2679.07draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2112.71draws/s]
#
#   0%|          | 1/350 [00:03<21:33,  3.71s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 68/4000 [00:00<00:05, 677.40draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▋         | 256/4000 [00:00<00:04, 837.67draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 485/4000 [00:00<00:03, 1034.44draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 736/4000 [00:00<00:02, 1255.37draws/s]
#
# Sampling 4 chains, 0 divergences:  25%|██▍       | 983/4000 [00:00<00:02, 1471.96draws/s]
#
# Sampling 4 chains, 0 divergences:  31%|███       | 1224/4000 [00:00<00:01, 1665.76draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1465/4000 [00:00<00:01, 1835.78draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1690/4000 [00:00<00:01, 1942.32draws/s]
#
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1928/4000 [00:00<00:01, 2053.33draws/s]
#
# Sampling 4 chains, 0 divergences:  54%|█████▍    | 2162/4000 [00:01<00:00, 2129.26draws/s]
#
# Sampling 4 chains, 0 divergences:  60%|██████    | 2420/4000 [00:01<00:00, 2246.69draws/s]
#
# Sampling 4 chains, 0 divergences:  67%|██████▋   | 2674/4000 [00:01<00:00, 2327.15draws/s]
#
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2923/4000 [00:01<00:00, 2373.51draws/s]
#
# Sampling 4 chains, 0 divergences:  79%|███████▉  | 3177/4000 [00:01<00:00, 2417.58draws/s]
#
# Sampling 4 chains, 0 divergences:  86%|████████▌ | 3445/4000 [00:01<00:00, 2489.26draws/s]
#
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3698/4000 [00:01<00:00, 2454.49draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2058.13draws/s]
#
#   1%|          | 2/350 [00:07<21:37,  3.73s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 116/4000 [00:00<00:03, 1159.68draws/s]
#
# Sampling 4 chains, 0 divergences:   7%|▋         | 297/4000 [00:00<00:02, 1298.95draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 467/4000 [00:00<00:02, 1397.50draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▋        | 652/4000 [00:00<00:02, 1506.37draws/s]
#
# Sampling 4 chains, 0 divergences:  21%|██        | 826/4000 [00:00<00:02, 1568.51draws/s]
#
# Sampling 4 chains, 0 divergences:  24%|██▍       | 969/4000 [00:00<00:02, 1513.29draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1138/4000 [00:00<00:01, 1561.41draws/s]
#
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1317/4000 [00:00<00:01, 1623.42draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1487/4000 [00:00<00:01, 1643.77draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1680/4000 [00:01<00:01, 1718.57draws/s]
#
# Sampling 4 chains, 0 divergences:  47%|████▋     | 1867/4000 [00:01<00:01, 1757.39draws/s]
#
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2067/4000 [00:01<00:01, 1823.66draws/s]
#
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2269/4000 [00:01<00:00, 1876.14draws/s]
#
# Sampling 4 chains, 0 divergences:  61%|██████▏   | 2458/4000 [00:01<00:00, 1871.83draws/s]
#
# Sampling 4 chains, 0 divergences:  66%|██████▌   | 2646/4000 [00:01<00:00, 1847.78draws/s]
#
# Sampling 4 chains, 0 divergences:  71%|███████   | 2844/4000 [00:01<00:00, 1885.31draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3035/4000 [00:01<00:00, 1888.00draws/s]
#
# Sampling 4 chains, 0 divergences:  81%|████████  | 3231/4000 [00:01<00:00, 1907.76draws/s]
#
# Sampling 4 chains, 0 divergences:  86%|████████▌ | 3423/4000 [00:01<00:00, 1880.72draws/s]
#
# Sampling 4 chains, 0 divergences:  91%|█████████ | 3622/4000 [00:02<00:00, 1909.81draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1687.19draws/s]
# The acceptance probability does not match the target. It is 0.7186277375067366, but should be close to 0.8. Try to increase the number of tuning steps.
#
#   1%|          | 3/350 [00:11<22:18,  3.86s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 101/4000 [00:00<00:03, 1004.21draws/s]
#
# Sampling 4 chains, 0 divergences:   8%|▊         | 305/4000 [00:00<00:03, 1182.23draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 487/4000 [00:00<00:02, 1321.08draws/s]
#
# Sampling 4 chains, 0 divergences:  17%|█▋        | 667/4000 [00:00<00:02, 1434.55draws/s]
#
# Sampling 4 chains, 0 divergences:  22%|██▏       | 866/4000 [00:00<00:02, 1564.81draws/s]
#
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1069/4000 [00:00<00:01, 1679.89draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1292/4000 [00:00<00:01, 1811.25draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1481/4000 [00:00<00:01, 1830.65draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1667/4000 [00:00<00:01, 1837.49draws/s]
#
# Sampling 4 chains, 0 divergences:  47%|████▋     | 1893/4000 [00:01<00:01, 1945.92draws/s]
#
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2096/4000 [00:01<00:00, 1970.25draws/s]
#
# Sampling 4 chains, 0 divergences:  58%|█████▊    | 2326/4000 [00:01<00:00, 2058.18draws/s]
#
# Sampling 4 chains, 0 divergences:  64%|██████▍   | 2562/4000 [00:01<00:00, 2138.99draws/s]
#
# Sampling 4 chains, 0 divergences:  70%|███████   | 2807/4000 [00:01<00:00, 2222.87draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3032/4000 [00:01<00:00, 2218.84draws/s]
#
# Sampling 4 chains, 0 divergences:  81%|████████▏ | 3256/4000 [00:01<00:00, 2189.99draws/s]
# Sampling 4 chains, 0 divergences:  87%|████████▋ | 3477/4000 [00:01<00:00, 2165.78draws/s]
#
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3696/4000 [00:01<00:00, 2170.95draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1882.38draws/s]
# The acceptance probability does not match the target. It is 0.8834074869560271, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
#
#   1%|          | 4/350 [00:19<28:51,  5.01s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 96/4000 [00:00<00:04, 949.77draws/s]
#
# Sampling 4 chains, 0 divergences:   7%|▋         | 281/4000 [00:00<00:03, 1112.03draws/s]
#
# Sampling 4 chains, 0 divergences:  13%|█▎        | 502/4000 [00:00<00:02, 1306.06draws/s]
#
# Sampling 4 chains, 0 divergences:  19%|█▉        | 756/4000 [00:00<00:02, 1528.70draws/s]
#
# Sampling 4 chains, 0 divergences:  25%|██▌       | 1009/4000 [00:00<00:01, 1733.51draws/s]
#
# Sampling 4 chains, 0 divergences:  30%|███       | 1210/4000 [00:00<00:01, 1807.00draws/s]
#
# Sampling 4 chains, 0 divergences:  36%|███▋      | 1456/4000 [00:00<00:01, 1962.38draws/s]
#
# Sampling 4 chains, 0 divergences:  43%|████▎     | 1705/4000 [00:00<00:01, 2095.18draws/s]
#
# Sampling 4 chains, 0 divergences:  49%|████▊     | 1946/4000 [00:00<00:00, 2177.16draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▌    | 2237/4000 [00:01<00:00, 2351.72draws/s]
#
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2529/4000 [00:01<00:00, 2495.30draws/s]
#
# Sampling 4 chains, 0 divergences:  70%|███████   | 2808/4000 [00:01<00:00, 2575.88draws/s]
#
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3094/4000 [00:01<00:00, 2650.44draws/s]
#
# Sampling 4 chains, 0 divergences:  85%|████████▍ | 3388/4000 [00:01<00:00, 2729.62draws/s]
#
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3666/4000 [00:01<00:00, 2386.76draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2099.52draws/s]
#
#   1%|▏         | 5/350 [00:23<26:30,  4.61s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 122/4000 [00:00<00:03, 1212.93draws/s]
#
# Sampling 4 chains, 0 divergences:   8%|▊         | 319/4000 [00:00<00:02, 1370.55draws/s]
#
# Sampling 4 chains, 0 divergences:  13%|█▎        | 523/4000 [00:00<00:02, 1517.87draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 719/4000 [00:00<00:02, 1626.98draws/s]
#
# Sampling 4 chains, 0 divergences:  23%|██▎       | 938/4000 [00:00<00:01, 1762.78draws/s]
#
# Sampling 4 chains, 0 divergences:  29%|██▉       | 1158/4000 [00:00<00:01, 1873.49draws/s]
#
# Sampling 4 chains, 0 divergences:  35%|███▌      | 1404/4000 [00:00<00:01, 2015.85draws/s]
#
# Sampling 4 chains, 0 divergences:  41%|████      | 1643/4000 [00:00<00:01, 2113.95draws/s]
#
# Sampling 4 chains, 0 divergences:  46%|████▋     | 1857/4000 [00:00<00:01, 2121.41draws/s]
#
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2092/4000 [00:01<00:00, 2181.52draws/s]
#
# Sampling 4 chains, 0 divergences:  58%|█████▊    | 2311/4000 [00:01<00:00, 2093.41draws/s]
#
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2535/4000 [00:01<00:00, 2133.69draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▉   | 2750/4000 [00:01<00:00, 2125.45draws/s]
#
# Sampling 4 chains, 0 divergences:  75%|███████▌  | 3003/4000 [00:01<00:00, 2231.31draws/s]
#
# Sampling 4 chains, 0 divergences:  81%|████████▏ | 3253/4000 [00:01<00:00, 2303.72draws/s]
#
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3506/4000 [00:01<00:00, 2366.75draws/s]
#
# Sampling 4 chains, 0 divergences:  94%|█████████▍| 3752/4000 [00:01<00:00, 2390.86draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1994.79draws/s]
#
#   2%|▏         | 6/350 [00:26<24:59,  4.36s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 40/4000 [00:00<00:09, 398.72draws/s]
#
# Sampling 4 chains, 0 divergences:   5%|▌         | 200/4000 [00:00<00:07, 514.34draws/s]
#
# Sampling 4 chains, 0 divergences:  11%|█         | 427/4000 [00:00<00:05, 669.66draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▋        | 652/4000 [00:00<00:03, 847.75draws/s]
#
# Sampling 4 chains, 0 divergences:  21%|██▏       | 858/4000 [00:00<00:03, 1029.23draws/s]
#
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1091/4000 [00:00<00:02, 1236.01draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1294/4000 [00:00<00:01, 1399.93draws/s]
#
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1523/4000 [00:00<00:01, 1583.73draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▎     | 1743/4000 [00:00<00:01, 1727.83draws/s]
#
# Sampling 4 chains, 0 divergences:  49%|████▉     | 1960/4000 [00:01<00:01, 1839.50draws/s]
#
# Sampling 4 chains, 0 divergences:  55%|█████▍    | 2191/4000 [00:01<00:00, 1958.28draws/s]
#
# Sampling 4 chains, 0 divergences:  61%|██████    | 2433/4000 [00:01<00:00, 2075.40draws/s]
#
# Sampling 4 chains, 0 divergences:  67%|██████▋   | 2679/4000 [00:01<00:00, 2176.89draws/s]
#
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2910/4000 [00:01<00:00, 2199.86draws/s]
#
# Sampling 4 chains, 0 divergences:  79%|███████▊  | 3141/4000 [00:01<00:00, 2230.58draws/s]
#
# Sampling 4 chains, 0 divergences:  85%|████████▍ | 3388/4000 [00:01<00:00, 2294.50draws/s]
#
# Sampling 4 chains, 0 divergences:  91%|█████████ | 3625/4000 [00:01<00:00, 2315.92draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1868.26draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   2%|▏         | 7/350 [00:30<24:09,  4.22s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 88/4000 [00:00<00:04, 877.49draws/s]
#
# Sampling 4 chains, 0 divergences:   8%|▊         | 303/4000 [00:00<00:03, 1066.93draws/s]
#
# Sampling 4 chains, 0 divergences:  14%|█▎        | 542/4000 [00:00<00:02, 1277.96draws/s]
#
# Sampling 4 chains, 0 divergences:  20%|█▉        | 789/4000 [00:00<00:02, 1492.37draws/s]
#
# Sampling 4 chains, 0 divergences:  26%|██▋       | 1055/4000 [00:00<00:01, 1718.40draws/s]
#
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1310/4000 [00:00<00:01, 1904.00draws/s]
#
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1528/4000 [00:00<00:01, 1978.76draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▎     | 1746/4000 [00:00<00:01, 2034.58draws/s]
#
# Sampling 4 chains, 0 divergences:  50%|████▉     | 1994/4000 [00:00<00:00, 2149.10draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▌    | 2249/4000 [00:01<00:00, 2253.87draws/s]
#
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2518/4000 [00:01<00:00, 2366.39draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▉   | 2776/4000 [00:01<00:00, 2426.04draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3033/4000 [00:01<00:00, 2466.61draws/s]
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3292/4000 [00:01<00:00, 2499.77draws/s]
#
# Sampling 4 chains, 0 divergences:  89%|████████▊ | 3545/4000 [00:01<00:00, 2502.16draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1947.83draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   2%|▏         | 8/350 [00:34<23:22,  4.10s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 31/4000 [00:00<00:12, 309.56draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▋         | 254/4000 [00:00<00:08, 417.38draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 494/4000 [00:00<00:06, 554.83draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 731/4000 [00:00<00:04, 719.93draws/s]
#
# Sampling 4 chains, 0 divergences:  24%|██▍       | 955/4000 [00:00<00:03, 903.82draws/s]
#
# Sampling 4 chains, 0 divergences:  30%|██▉       | 1192/4000 [00:00<00:02, 1109.15draws/s]
#
# Sampling 4 chains, 0 divergences:  36%|███▌      | 1424/4000 [00:00<00:01, 1314.70draws/s]
#
# Sampling 4 chains, 0 divergences:  41%|████      | 1649/4000 [00:00<00:01, 1499.06draws/s]
#
# Sampling 4 chains, 0 divergences:  47%|████▋     | 1891/4000 [00:00<00:01, 1691.68draws/s]
#
# Sampling 4 chains, 0 divergences:  54%|█████▍    | 2168/4000 [00:01<00:00, 1914.78draws/s]
#
# Sampling 4 chains, 0 divergences:  61%|██████    | 2434/4000 [00:01<00:00, 2089.18draws/s]
#
# Sampling 4 chains, 0 divergences:  68%|██████▊   | 2706/4000 [00:01<00:00, 2242.10draws/s]
#
# Sampling 4 chains, 0 divergences:  74%|███████▍  | 2961/4000 [00:01<00:00, 2326.33draws/s]
#
# Sampling 4 chains, 0 divergences:  81%|████████  | 3244/4000 [00:01<00:00, 2456.30draws/s]
#
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3507/4000 [00:01<00:00, 2450.11draws/s]
#
# Sampling 4 chains, 0 divergences:  94%|█████████▍| 3764/4000 [00:01<00:00, 1587.85draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1808.17draws/s]
#
#   3%|▎         | 9/350 [00:38<23:04,  4.06s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|▏         | 56/4000 [00:00<00:07, 558.79draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▌         | 229/4000 [00:00<00:05, 700.60draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 470/4000 [00:00<00:03, 889.74draws/s]
#
# Sampling 4 chains, 0 divergences:  17%|█▋        | 691/4000 [00:00<00:03, 1083.52draws/s]
#
# Sampling 4 chains, 0 divergences:  23%|██▎       | 909/4000 [00:00<00:02, 1275.51draws/s]
#
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1097/4000 [00:00<00:02, 1411.45draws/s]
#
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1313/4000 [00:00<00:01, 1574.86draws/s]
#
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1524/4000 [00:00<00:01, 1704.43draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1769/4000 [00:00<00:01, 1874.11draws/s]
#
# Sampling 4 chains, 0 divergences:  50%|████▉     | 1997/4000 [00:01<00:01, 1978.83draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▌    | 2238/4000 [00:01<00:00, 2089.73draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▎   | 2500/4000 [00:01<00:00, 2224.60draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▉   | 2771/4000 [00:01<00:00, 2350.10draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3024/4000 [00:01<00:00, 2399.72draws/s]
#
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3272/4000 [00:01<00:00, 2408.34draws/s]
#
# Sampling 4 chains, 0 divergences:  89%|████████▊ | 3543/4000 [00:01<00:00, 2487.53draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2034.87draws/s]
#
#   3%|▎         | 10/350 [00:42<22:25,  3.96s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 63/4000 [00:00<00:06, 617.72draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▌         | 236/4000 [00:00<00:04, 765.32draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 468/4000 [00:00<00:03, 957.61draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▋        | 652/4000 [00:00<00:02, 1118.44draws/s]
#
# Sampling 4 chains, 0 divergences:  22%|██▏       | 878/4000 [00:00<00:02, 1315.13draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1105/4000 [00:00<00:01, 1505.00draws/s]
#
# Sampling 4 chains, 0 divergences:  34%|███▎      | 1341/4000 [00:00<00:01, 1686.56draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1550/4000 [00:00<00:01, 1789.71draws/s]
#
# Sampling 4 chains, 0 divergences:  45%|████▍     | 1783/4000 [00:00<00:01, 1923.35draws/s]
#
# Sampling 4 chains, 0 divergences:  50%|█████     | 2014/4000 [00:01<00:00, 2023.42draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▌    | 2246/4000 [00:01<00:00, 2102.13draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2478/4000 [00:01<00:00, 2162.46draws/s]
#
# Sampling 4 chains, 0 divergences:  68%|██████▊   | 2720/4000 [00:01<00:00, 2232.96draws/s]
#
# Sampling 4 chains, 0 divergences:  74%|███████▍  | 2950/4000 [00:01<00:00, 2231.23draws/s]
#
# Sampling 4 chains, 0 divergences:  79%|███████▉  | 3178/4000 [00:01<00:00, 2187.03draws/s]
#
# Sampling 4 chains, 0 divergences:  85%|████████▌ | 3400/4000 [00:01<00:00, 2139.26draws/s]
#
# Sampling 4 chains, 0 divergences:  90%|█████████ | 3617/4000 [00:01<00:00, 2060.08draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1823.41draws/s]
#
#   3%|▎         | 11/350 [00:46<22:21,  3.96s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 88/4000 [00:00<00:04, 878.70draws/s]
#
# Sampling 4 chains, 0 divergences:   8%|▊         | 305/4000 [00:00<00:03, 1069.63draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 492/4000 [00:00<00:02, 1226.79draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 714/4000 [00:00<00:02, 1413.98draws/s]
#
# Sampling 4 chains, 0 divergences:  23%|██▎       | 911/4000 [00:00<00:02, 1540.93draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1133/4000 [00:00<00:01, 1695.10draws/s]
#
# Sampling 4 chains, 0 divergences:  34%|███▎      | 1341/4000 [00:00<00:01, 1794.45draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1572/4000 [00:00<00:01, 1921.55draws/s]
#
# Sampling 4 chains, 0 divergences:  46%|████▌     | 1820/4000 [00:00<00:01, 2060.69draws/s]
#
# Sampling 4 chains, 0 divergences:  51%|█████▏    | 2055/4000 [00:01<00:00, 2138.78draws/s]
#
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2276/4000 [00:01<00:00, 2141.25draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2495/4000 [00:01<00:00, 2143.29draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▉   | 2754/4000 [00:01<00:00, 2259.41draws/s]
#
# Sampling 4 chains, 0 divergences:  75%|███████▍  | 2986/4000 [00:01<00:00, 2272.88draws/s]
#
# Sampling 4 chains, 0 divergences:  80%|████████  | 3217/4000 [00:01<00:00, 2279.60draws/s]
#
# Sampling 4 chains, 0 divergences:  86%|████████▋ | 3457/4000 [00:01<00:00, 2313.14draws/s]
# Sampling 4 chains, 0 divergences:  93%|█████████▎| 3716/4000 [00:01<00:00, 2386.60draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1920.95draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   3%|▎         | 12/350 [00:49<22:05,  3.92s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 127/4000 [00:00<00:03, 1256.44draws/s]
#
# Sampling 4 chains, 0 divergences:   9%|▊         | 345/4000 [00:00<00:02, 1438.90draws/s]
#
# Sampling 4 chains, 0 divergences:  13%|█▎        | 538/4000 [00:00<00:02, 1556.74draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 732/4000 [00:00<00:01, 1654.46draws/s]
#
# Sampling 4 chains, 0 divergences:  23%|██▎       | 926/4000 [00:00<00:01, 1729.04draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1113/4000 [00:00<00:01, 1768.58draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1294/4000 [00:00<00:01, 1780.78draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1478/4000 [00:00<00:01, 1795.98draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1671/4000 [00:00<00:01, 1830.95draws/s]
#
# Sampling 4 chains, 0 divergences:  46%|████▋     | 1860/4000 [00:01<00:01, 1843.53draws/s]
#
# Sampling 4 chains, 0 divergences:  51%|█████     | 2043/4000 [00:01<00:01, 1815.21draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▋    | 2250/4000 [00:01<00:00, 1884.30draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2461/4000 [00:01<00:00, 1945.57draws/s]
#
# Sampling 4 chains, 0 divergences:  66%|██████▋   | 2656/4000 [00:01<00:00, 1899.51draws/s]
#
# Sampling 4 chains, 0 divergences:  71%|███████▏  | 2855/4000 [00:01<00:00, 1919.49draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▋  | 3055/4000 [00:01<00:00, 1939.96draws/s]
#
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3262/4000 [00:01<00:00, 1974.68draws/s]
#
# Sampling 4 chains, 0 divergences:  86%|████████▋ | 3460/4000 [00:01<00:00, 1929.02draws/s]
#
# Sampling 4 chains, 0 divergences:  91%|█████████▏| 3654/4000 [00:01<00:00, 1922.17draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1723.69draws/s]
# The acceptance probability does not match the target. It is 0.7083736357796401, but should be close to 0.8. Try to increase the number of tuning steps.
#
#   4%|▎         | 13/350 [00:55<25:00,  4.45s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   0%|          | 8/4000 [00:00<00:50, 78.74draws/s]
#
# Sampling 4 chains, 0 divergences:   4%|▍         | 155/4000 [00:00<00:34, 109.94draws/s]
#
# Sampling 4 chains, 0 divergences:  10%|▉         | 381/4000 [00:00<00:23, 153.84draws/s]
#
# Sampling 4 chains, 0 divergences:  14%|█▍        | 564/4000 [00:00<00:16, 212.12draws/s]
#
# Sampling 4 chains, 0 divergences:  19%|█▉        | 771/4000 [00:00<00:11, 290.25draws/s]
#
# Sampling 4 chains, 0 divergences:  25%|██▍       | 991/4000 [00:00<00:07, 392.26draws/s]
#
# Sampling 4 chains, 0 divergences:  31%|███       | 1224/4000 [00:00<00:05, 522.55draws/s]
#
# Sampling 4 chains, 0 divergences:  36%|███▋      | 1458/4000 [00:00<00:03, 681.27draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1673/4000 [00:00<00:02, 856.85draws/s]
#
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1902/4000 [00:01<00:01, 1054.67draws/s]
#
# Sampling 4 chains, 0 divergences:  53%|█████▎    | 2131/4000 [00:01<00:01, 1258.05draws/s]
#
# Sampling 4 chains, 0 divergences:  59%|█████▊    | 2349/4000 [00:01<00:01, 1439.07draws/s]
#
# Sampling 4 chains, 0 divergences:  65%|██████▌   | 2612/4000 [00:01<00:00, 1664.91draws/s]
#
# Sampling 4 chains, 0 divergences:  72%|███████▏  | 2863/4000 [00:01<00:00, 1851.27draws/s]
#
# Sampling 4 chains, 0 divergences:  78%|███████▊  | 3100/4000 [00:01<00:00, 1976.77draws/s]
#
# Sampling 4 chains, 0 divergences:  84%|████████▍ | 3366/4000 [00:01<00:00, 2141.42draws/s]
#
# Sampling 4 chains, 0 divergences:  91%|█████████ | 3641/4000 [00:01<00:00, 2292.29draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1900.19draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   4%|▍         | 14/350 [00:59<23:58,  4.28s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 116/4000 [00:00<00:03, 1157.70draws/s]
#
# Sampling 4 chains, 0 divergences:   9%|▊         | 345/4000 [00:00<00:02, 1357.92draws/s]
#
# Sampling 4 chains, 0 divergences:  14%|█▍        | 565/4000 [00:00<00:02, 1532.00draws/s]
#
# Sampling 4 chains, 0 divergences:  20%|█▉        | 782/4000 [00:00<00:01, 1678.68draws/s]
#
# Sampling 4 chains, 0 divergences:  26%|██▌       | 1022/4000 [00:00<00:01, 1843.99draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1273/4000 [00:00<00:01, 2002.93draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▊      | 1543/4000 [00:00<00:01, 2170.95draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1766/4000 [00:00<00:01, 2179.72draws/s]
#
# Sampling 4 chains, 0 divergences:  51%|█████     | 2044/4000 [00:00<00:00, 2330.09draws/s]
#
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2283/4000 [00:01<00:00, 2318.32draws/s]
#
# Sampling 4 chains, 0 divergences:  64%|██████▍   | 2555/4000 [00:01<00:00, 2425.72draws/s]
#
# Sampling 4 chains, 0 divergences:  71%|███████   | 2821/4000 [00:01<00:00, 2491.24draws/s]
#
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3082/4000 [00:01<00:00, 2525.31draws/s]
#
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3337/4000 [00:01<00:00, 2471.88draws/s]
#
# Sampling 4 chains, 0 divergences:  90%|████████▉ | 3597/4000 [00:01<00:00, 2506.93draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2060.90draws/s]
# The acceptance probability does not match the target. It is 0.7045804085782738, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8891864709514933, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
#
#   4%|▍         | 15/350 [01:03<22:55,  4.11s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 65/4000 [00:00<00:06, 649.64draws/s]
#
# Sampling 4 chains, 0 divergences:   7%|▋         | 269/4000 [00:00<00:04, 816.48draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 475/4000 [00:00<00:03, 995.84draws/s]
#
# Sampling 4 chains, 0 divergences:  17%|█▋        | 674/4000 [00:00<00:02, 1171.35draws/s]
#
# Sampling 4 chains, 0 divergences:  22%|██▏       | 876/4000 [00:00<00:02, 1335.75draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1103/4000 [00:00<00:01, 1523.86draws/s]
#
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1314/4000 [00:00<00:01, 1660.78draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▊      | 1541/4000 [00:00<00:01, 1805.40draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1767/4000 [00:00<00:01, 1920.89draws/s]
# Sampling 4 chains, 0 divergences:  50%|████▉     | 1983/4000 [00:01<00:01, 1985.83draws/s]
#
# Sampling 4 chains, 0 divergences:  55%|█████▌    | 2213/4000 [00:01<00:00, 2068.70draws/s]
#
# Sampling 4 chains, 0 divergences:  61%|██████    | 2437/4000 [00:01<00:00, 2116.96draws/s]
#
# Sampling 4 chains, 0 divergences:  67%|██████▋   | 2673/4000 [00:01<00:00, 2184.05draws/s]
#
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2907/4000 [00:01<00:00, 2226.60draws/s]
#
# Sampling 4 chains, 0 divergences:  79%|███████▊  | 3142/4000 [00:01<00:00, 2260.91draws/s]
#
# Sampling 4 chains, 0 divergences:  84%|████████▍ | 3380/4000 [00:01<00:00, 2295.20draws/s]
#
# Sampling 4 chains, 0 divergences:  91%|█████████ | 3629/4000 [00:01<00:00, 2350.30draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2007.81draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   5%|▍         | 16/350 [01:07<22:17,  4.00s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 31/4000 [00:00<00:12, 306.08draws/s]
#
# Sampling 4 chains, 0 divergences:   5%|▌         | 201/4000 [00:00<00:09, 405.86draws/s]
#
# Sampling 4 chains, 0 divergences:  10%|█         | 417/4000 [00:00<00:06, 536.56draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▌        | 649/4000 [00:00<00:04, 697.33draws/s]
#
# Sampling 4 chains, 0 divergences:  21%|██        | 846/4000 [00:00<00:03, 863.81draws/s]
#
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1089/4000 [00:00<00:02, 1070.58draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1282/4000 [00:00<00:02, 1235.17draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1469/4000 [00:00<00:01, 1371.51draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1697/4000 [00:00<00:01, 1556.02draws/s]
#
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1913/4000 [00:01<00:01, 1696.43draws/s]
#
# Sampling 4 chains, 0 divergences:  54%|█████▍    | 2151/4000 [00:01<00:00, 1854.93draws/s]
#
# Sampling 4 chains, 0 divergences:  59%|█████▉    | 2376/4000 [00:01<00:00, 1956.29draws/s]
#
# Sampling 4 chains, 0 divergences:  65%|██████▌   | 2602/4000 [00:01<00:00, 2036.36draws/s]
#
# Sampling 4 chains, 0 divergences:  71%|███████   | 2831/4000 [00:01<00:00, 2106.03draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▋  | 3057/4000 [00:01<00:00, 2146.79draws/s]
#
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3280/4000 [00:01<00:00, 2132.38draws/s]
#
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3500/4000 [00:01<00:00, 2076.24draws/s]
#
# Sampling 4 chains, 0 divergences:  93%|█████████▎| 3737/4000 [00:01<00:00, 2153.28draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1837.02draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   5%|▍         | 17/350 [01:10<22:07,  3.99s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 84/4000 [00:00<00:04, 838.15draws/s]
#
# Sampling 4 chains, 0 divergences:   8%|▊         | 305/4000 [00:00<00:03, 1029.16draws/s]
#
# Sampling 4 chains, 0 divergences:  14%|█▍        | 551/4000 [00:00<00:02, 1246.64draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 738/4000 [00:00<00:02, 1382.25draws/s]
#
# Sampling 4 chains, 0 divergences:  24%|██▍       | 965/4000 [00:00<00:01, 1565.83draws/s]
#
# Sampling 4 chains, 0 divergences:  30%|██▉       | 1182/4000 [00:00<00:01, 1708.18draws/s]
#
# Sampling 4 chains, 0 divergences:  35%|███▌      | 1405/4000 [00:00<00:01, 1836.41draws/s]
#
# Sampling 4 chains, 0 divergences:  41%|████      | 1639/4000 [00:00<00:01, 1963.07draws/s]
#
# Sampling 4 chains, 0 divergences:  46%|████▌     | 1847/4000 [00:00<00:01, 1961.77draws/s]
#
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2078/4000 [00:01<00:00, 2053.90draws/s]
#
# Sampling 4 chains, 0 divergences:  58%|█████▊    | 2303/4000 [00:01<00:00, 2108.42draws/s]
#
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2519/4000 [00:01<00:00, 2104.78draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▉   | 2758/4000 [00:01<00:00, 2180.67draws/s]
#
# Sampling 4 chains, 0 divergences:  75%|███████▍  | 2994/4000 [00:01<00:00, 2229.67draws/s]
#
# Sampling 4 chains, 0 divergences:  81%|████████  | 3230/4000 [00:01<00:00, 2264.69draws/s]
#
# Sampling 4 chains, 0 divergences:  86%|████████▋ | 3459/4000 [00:01<00:00, 2219.54draws/s]
#
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3686/4000 [00:01<00:00, 2232.26draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1976.53draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   5%|▌         | 18/350 [01:14<21:46,  3.93s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 24/4000 [00:00<00:16, 238.47draws/s]
#
# Sampling 4 chains, 0 divergences:   5%|▍         | 197/4000 [00:00<00:11, 321.63draws/s]
#
# Sampling 4 chains, 0 divergences:  10%|▉         | 392/4000 [00:00<00:08, 429.09draws/s]
#
# Sampling 4 chains, 0 divergences:  15%|█▌        | 608/4000 [00:00<00:06, 564.81draws/s]
#
# Sampling 4 chains, 0 divergences:  20%|██        | 815/4000 [00:00<00:04, 722.35draws/s]
#
# Sampling 4 chains, 0 divergences:  26%|██▌       | 1041/4000 [00:00<00:03, 907.45draws/s]
#
# Sampling 4 chains, 0 divergences:  31%|███▏      | 1258/4000 [00:00<00:02, 1099.25draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1481/4000 [00:00<00:01, 1296.19draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1699/4000 [00:00<00:01, 1473.11draws/s]
#
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1922/4000 [00:01<00:01, 1639.93draws/s]
#
# Sampling 4 chains, 0 divergences:  54%|█████▎    | 2142/4000 [00:01<00:01, 1775.37draws/s]
#
# Sampling 4 chains, 0 divergences:  59%|█████▉    | 2374/4000 [00:01<00:00, 1908.76draws/s]
#
# Sampling 4 chains, 0 divergences:  65%|██████▍   | 2593/4000 [00:01<00:00, 1977.36draws/s]
#
# Sampling 4 chains, 0 divergences:  71%|███████▏  | 2853/4000 [00:01<00:00, 2130.18draws/s]
#
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3084/4000 [00:01<00:00, 2130.66draws/s]
#
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3310/4000 [00:01<00:00, 1994.05draws/s]
#
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3520/4000 [00:01<00:00, 1888.37draws/s]
#
# Sampling 4 chains, 0 divergences:  93%|█████████▎| 3718/4000 [00:01<00:00, 1798.20draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1721.00draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   5%|▌         | 19/350 [01:18<22:00,  3.99s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 68/4000 [00:00<00:05, 679.02draws/s]
#
# Sampling 4 chains, 0 divergences:   7%|▋         | 294/4000 [00:00<00:04, 859.27draws/s]
#
# Sampling 4 chains, 0 divergences:  13%|█▎        | 521/4000 [00:00<00:03, 1055.37draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 719/4000 [00:00<00:02, 1226.11draws/s]
# Sampling 4 chains, 0 divergences:  23%|██▎       | 920/4000 [00:00<00:02, 1387.26draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1138/4000 [00:00<00:01, 1556.46draws/s]
#
# Sampling 4 chains, 0 divergences:  35%|███▍      | 1382/4000 [00:00<00:01, 1745.61draws/s]
#
# Sampling 4 chains, 0 divergences:  40%|███▉      | 1581/4000 [00:00<00:01, 1808.36draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1780/4000 [00:00<00:01, 1845.44draws/s]
#
# Sampling 4 chains, 0 divergences:  49%|████▉     | 1979/4000 [00:01<00:01, 1885.73draws/s]
#
# Sampling 4 chains, 0 divergences:  55%|█████▍    | 2199/4000 [00:01<00:00, 1964.90draws/s]
#
# Sampling 4 chains, 0 divergences:  60%|██████    | 2407/4000 [00:01<00:00, 1997.24draws/s]
#
# Sampling 4 chains, 0 divergences:  66%|██████▌   | 2633/4000 [00:01<00:00, 2069.00draws/s]
#
# Sampling 4 chains, 0 divergences:  72%|███████▏  | 2860/4000 [00:01<00:00, 2124.19draws/s]
#
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3076/4000 [00:01<00:00, 2077.14draws/s]
#
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3294/4000 [00:01<00:00, 2104.77draws/s]
#
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3521/4000 [00:01<00:00, 2150.94draws/s]
#
# Sampling 4 chains, 0 divergences:  93%|█████████▎| 3738/4000 [00:01<00:00, 2056.80draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1887.60draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   6%|▌         | 20/350 [01:22<21:46,  3.96s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 40/4000 [00:00<00:09, 399.06draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▌         | 226/4000 [00:00<00:07, 522.04draws/s]
#
# Sampling 4 chains, 0 divergences:  11%|█▏        | 457/4000 [00:00<00:05, 679.42draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▌        | 642/4000 [00:00<00:04, 838.30draws/s]
#
# Sampling 4 chains, 0 divergences:  21%|██        | 825/4000 [00:00<00:03, 1000.73draws/s]
#
# Sampling 4 chains, 0 divergences:  26%|██▌       | 1026/4000 [00:00<00:02, 1177.82draws/s]
#
# Sampling 4 chains, 0 divergences:  31%|███       | 1233/4000 [00:00<00:02, 1350.32draws/s]
#
# Sampling 4 chains, 0 divergences:  36%|███▌      | 1434/4000 [00:00<00:01, 1496.67draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1662/4000 [00:00<00:01, 1666.59draws/s]
#
# Sampling 4 chains, 0 divergences:  46%|████▋     | 1859/4000 [00:01<00:01, 1742.60draws/s]
#
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2080/4000 [00:01<00:01, 1860.33draws/s]
#
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2284/4000 [00:01<00:00, 1834.07draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2494/4000 [00:01<00:00, 1906.00draws/s]
#
# Sampling 4 chains, 0 divergences:  68%|██████▊   | 2732/4000 [00:01<00:00, 2025.09draws/s]
#
# Sampling 4 chains, 0 divergences:  74%|███████▍  | 2972/4000 [00:01<00:00, 2124.61draws/s]
#
# Sampling 4 chains, 0 divergences:  80%|███████▉  | 3192/4000 [00:01<00:00, 2092.27draws/s]
#
# Sampling 4 chains, 0 divergences:  85%|████████▌ | 3411/4000 [00:01<00:00, 2118.55draws/s]
#
# Sampling 4 chains, 0 divergences:  91%|█████████ | 3627/4000 [00:01<00:00, 2124.77draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1781.50draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   6%|▌         | 21/350 [01:26<21:50,  3.98s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 42/4000 [00:00<00:09, 417.55draws/s]
#
# Sampling 4 chains, 0 divergences:   5%|▌         | 201/4000 [00:00<00:07, 535.93draws/s]
#
# Sampling 4 chains, 0 divergences:  11%|█         | 422/4000 [00:00<00:05, 693.27draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▌        | 643/4000 [00:00<00:03, 872.96draws/s]
#
# Sampling 4 chains, 0 divergences:  21%|██▏       | 856/4000 [00:00<00:02, 1060.58draws/s]
#
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1087/4000 [00:00<00:02, 1265.48draws/s]
#
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1323/4000 [00:00<00:01, 1469.85draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1557/4000 [00:00<00:01, 1652.94draws/s]
#
# Sampling 4 chains, 0 divergences:  45%|████▍     | 1792/4000 [00:00<00:01, 1814.02draws/s]
#
# Sampling 4 chains, 0 divergences:  50%|█████     | 2009/4000 [00:01<00:01, 1875.57draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▋    | 2251/4000 [00:01<00:00, 2009.52draws/s]
#
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2512/4000 [00:01<00:00, 2157.93draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▉   | 2756/4000 [00:01<00:00, 2234.32draws/s]
#
# Sampling 4 chains, 0 divergences:  76%|███████▌  | 3022/4000 [00:01<00:00, 2342.11draws/s]
#
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3284/4000 [00:01<00:00, 2417.90draws/s]
#
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3534/4000 [00:01<00:00, 2419.63draws/s]
#
# Sampling 4 chains, 0 divergences:  95%|█████████▍| 3782/4000 [00:01<00:00, 1906.55draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1927.99draws/s]
#
#   6%|▋         | 22/350 [01:30<21:31,  3.94s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 136/4000 [00:00<00:02, 1355.24draws/s]
#
# Sampling 4 chains, 0 divergences:  10%|▉         | 391/4000 [00:00<00:02, 1576.32draws/s]
#
# Sampling 4 chains, 0 divergences:  15%|█▌        | 603/4000 [00:00<00:01, 1705.23draws/s]
#
# Sampling 4 chains, 0 divergences:  21%|██        | 825/4000 [00:00<00:01, 1832.45draws/s]
#
# Sampling 4 chains, 0 divergences:  25%|██▌       | 1014/4000 [00:00<00:01, 1845.66draws/s]
#
# Sampling 4 chains, 0 divergences:  31%|███       | 1234/4000 [00:00<00:01, 1939.30draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1464/4000 [00:00<00:01, 2034.21draws/s]
#
# Sampling 4 chains, 0 divergences:  43%|████▎     | 1703/4000 [00:00<00:01, 2128.85draws/s]
#
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1931/4000 [00:00<00:00, 2171.74draws/s]
#
# Sampling 4 chains, 0 divergences:  54%|█████▎    | 2148/4000 [00:01<00:00, 2169.44draws/s]
#
# Sampling 4 chains, 0 divergences:  59%|█████▉    | 2364/4000 [00:01<00:00, 2121.75draws/s]
#
# Sampling 4 chains, 0 divergences:  65%|██████▍   | 2589/4000 [00:01<00:00, 2153.83draws/s]
#
# Sampling 4 chains, 0 divergences:  71%|███████   | 2830/4000 [00:01<00:00, 2222.29draws/s]
#
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3068/4000 [00:01<00:00, 2267.30draws/s]
#
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3318/4000 [00:01<00:00, 2331.00draws/s]
#
# Sampling 4 chains, 0 divergences:  89%|████████▉ | 3552/4000 [00:01<00:00, 2314.47draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2006.36draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#   7%|▋         | 23/350 [01:36<23:58,  4.40s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
# Sampling 4 chains, 0 divergences:   1%|          | 48/4000 [00:00<00:08, 469.63draws/s]
#
# Sampling 4 chains, 0 divergences:   5%|▌         | 211/4000 [00:00<00:06, 597.13draws/s]
#
# Sampling 4 chains, 0 divergences:  11%|█         | 432/4000 [00:00<00:04, 764.45draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▌        | 648/4000 [00:00<00:03, 947.58draws/s]
#
# Sampling 4 chains, 0 divergences:  22%|██▏       | 869/4000 [00:00<00:02, 1143.21draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1120/4000 [00:00<00:02, 1365.83draws/s]
#
# Sampling 4 chains, 0 divergences:  34%|███▍      | 1377/4000 [00:00<00:01, 1588.22draws/s]
#
# Sampling 4 chains, 0 divergences:  40%|████      | 1605/4000 [00:00<00:01, 1746.40draws/s]
#
# Sampling 4 chains, 0 divergences:  46%|████▌     | 1848/4000 [00:00<00:01, 1906.29draws/s]
#
# Sampling 4 chains, 0 divergences:  52%|█████▏    | 2084/4000 [00:01<00:00, 2022.02draws/s]
#
# Sampling 4 chains, 0 divergences:  59%|█████▊    | 2348/4000 [00:01<00:00, 2174.33draws/s]
#
# Sampling 4 chains, 0 divergences:  65%|██████▍   | 2587/4000 [00:01<00:00, 2210.46draws/s]
#
# Sampling 4 chains, 0 divergences:  71%|███████   | 2831/4000 [00:01<00:00, 2273.23draws/s]
#
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3075/4000 [00:01<00:00, 2320.52draws/s]
#
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3335/4000 [00:01<00:00, 2396.34draws/s]
#
# Sampling 4 chains, 0 divergences:  90%|████████▉ | 3581/4000 [00:01<00:00, 2407.57draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1934.60draws/s]
#
#   7%|▋         | 24/350 [01:39<22:59,  4.23s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# ...
#
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3672/4000 [00:01<00:00, 2134.74draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1843.11draws/s]
#
#  97%|█████████▋| 242/250 [16:22<00:31,  3.91s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 77/4000 [00:00<00:05, 766.29draws/s]
#
# Sampling 4 chains, 0 divergences:   7%|▋         | 278/4000 [00:00<00:03, 939.46draws/s]
#
# Sampling 4 chains, 0 divergences:  13%|█▎        | 502/4000 [00:00<00:03, 1135.76draws/s]
#
# Sampling 4 chains, 0 divergences:  19%|█▉        | 753/4000 [00:00<00:02, 1358.83draws/s]
#
# Sampling 4 chains, 0 divergences:  25%|██▌       | 1000/4000 [00:00<00:01, 1570.72draws/s]
#
# Sampling 4 chains, 0 divergences:  31%|███       | 1225/4000 [00:00<00:01, 1725.41draws/s]
#
# Sampling 4 chains, 0 divergences:  36%|███▋      | 1459/4000 [00:00<00:01, 1871.81draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1669/4000 [00:00<00:01, 1934.53draws/s]
#
# Sampling 4 chains, 0 divergences:  47%|████▋     | 1887/4000 [00:00<00:01, 2001.17draws/s]
#
# Sampling 4 chains, 0 divergences:  53%|█████▎    | 2132/4000 [00:01<00:00, 2116.40draws/s]
#
# Sampling 4 chains, 0 divergences:  60%|█████▉    | 2397/4000 [00:01<00:00, 2252.01draws/s]
#
# Sampling 4 chains, 0 divergences:  66%|██████▋   | 2657/4000 [00:01<00:00, 2344.72draws/s]
#
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2901/4000 [00:01<00:00, 2372.12draws/s]
#
# Sampling 4 chains, 0 divergences:  79%|███████▉  | 3161/4000 [00:01<00:00, 2433.85draws/s]
#
# Sampling 4 chains, 0 divergences:  86%|████████▌ | 3428/4000 [00:01<00:00, 2499.11draws/s]
#
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3698/4000 [00:01<00:00, 2553.98draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2073.05draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#  97%|█████████▋| 243/250 [16:26<00:26,  3.84s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 42/4000 [00:00<00:09, 419.29draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▋         | 252/4000 [00:00<00:06, 551.76draws/s]
#
# Sampling 4 chains, 0 divergences:  11%|█▏        | 457/4000 [00:00<00:05, 706.70draws/s]
#
# Sampling 4 chains, 0 divergences:  17%|█▋        | 664/4000 [00:00<00:03, 880.56draws/s]
#
# Sampling 4 chains, 0 divergences:  22%|██▏       | 889/4000 [00:00<00:02, 1077.04draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1104/4000 [00:00<00:02, 1266.61draws/s]
#
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1320/4000 [00:00<00:01, 1444.74draws/s]
#
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1516/4000 [00:00<00:01, 1566.18draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1754/4000 [00:00<00:01, 1744.87draws/s]
#
# Sampling 4 chains, 0 divergences:  49%|████▉     | 1960/4000 [00:01<00:01, 1815.13draws/s]
#
# Sampling 4 chains, 0 divergences:  55%|█████▍    | 2188/4000 [00:01<00:00, 1929.88draws/s]
#
# Sampling 4 chains, 0 divergences:  60%|██████    | 2417/4000 [00:01<00:00, 2020.09draws/s]
#
# Sampling 4 chains, 0 divergences:  66%|██████▌   | 2633/4000 [00:01<00:00, 2036.31draws/s]
#
# Sampling 4 chains, 0 divergences:  72%|███████▏  | 2863/4000 [00:01<00:00, 2108.06draws/s]
#
# Sampling 4 chains, 0 divergences:  77%|███████▋  | 3082/4000 [00:01<00:00, 2080.14draws/s]
#
# Sampling 4 chains, 0 divergences:  82%|████████▏ | 3296/4000 [00:01<00:00, 2070.17draws/s]
#
# Sampling 4 chains, 0 divergences:  88%|████████▊ | 3513/4000 [00:01<00:00, 2097.30draws/s]
#
# Sampling 4 chains, 0 divergences:  93%|█████████▎| 3726/4000 [00:01<00:00, 2074.61draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1857.00draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#  98%|█████████▊| 244/250 [16:30<00:23,  3.87s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 127/4000 [00:00<00:03, 1263.74draws/s]
#
# Sampling 4 chains, 0 divergences:   9%|▊         | 344/4000 [00:00<00:02, 1443.56draws/s]
#
# Sampling 4 chains, 0 divergences:  14%|█▍        | 566/4000 [00:00<00:02, 1612.01draws/s]
#
# Sampling 4 chains, 0 divergences:  20%|██        | 817/4000 [00:00<00:01, 1804.21draws/s]
#
# Sampling 4 chains, 0 divergences:  26%|██▌       | 1045/4000 [00:00<00:01, 1921.27draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1284/4000 [00:00<00:01, 2040.90draws/s]
#
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1511/4000 [00:00<00:01, 2099.00draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1750/4000 [00:00<00:01, 2175.37draws/s]
#
# Sampling 4 chains, 0 divergences:  50%|████▉     | 1993/4000 [00:00<00:00, 2245.59draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▌    | 2245/4000 [00:01<00:00, 2319.50draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2478/4000 [00:01<00:00, 2273.30draws/s]
#
# Sampling 4 chains, 0 divergences:  68%|██████▊   | 2717/4000 [00:01<00:00, 2305.90draws/s]
#
# Sampling 4 chains, 0 divergences:  74%|███████▎  | 2949/4000 [00:01<00:00, 2228.11draws/s]
#
# Sampling 4 chains, 0 divergences:  79%|███████▉  | 3174/4000 [00:01<00:00, 2234.15draws/s]
#
# Sampling 4 chains, 0 divergences:  86%|████████▌ | 3424/4000 [00:01<00:00, 2306.88draws/s]
#
# Sampling 4 chains, 0 divergences:  92%|█████████▏| 3674/4000 [00:01<00:00, 2360.34draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2037.66draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#  98%|█████████▊| 245/250 [16:36<00:22,  4.57s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   3%|▎         | 138/4000 [00:00<00:02, 1377.44draws/s]
#
# Sampling 4 chains, 0 divergences:   9%|▊         | 347/4000 [00:00<00:02, 1534.35draws/s]
#
# Sampling 4 chains, 0 divergences:  13%|█▎        | 532/4000 [00:00<00:02, 1616.56draws/s]
#
# Sampling 4 chains, 0 divergences:  19%|█▉        | 750/4000 [00:00<00:01, 1749.15draws/s]
#
# Sampling 4 chains, 0 divergences:  23%|██▎       | 906/4000 [00:00<00:01, 1686.84draws/s]
#
# Sampling 4 chains, 0 divergences:  27%|██▋       | 1065/4000 [00:00<00:01, 1655.21draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1275/4000 [00:00<00:01, 1762.79draws/s]
#
# Sampling 4 chains, 0 divergences:  37%|███▋      | 1472/4000 [00:00<00:01, 1819.57draws/s]
#
# Sampling 4 chains, 0 divergences:  42%|████▏     | 1697/4000 [00:00<00:01, 1928.96draws/s]
#
# Sampling 4 chains, 0 divergences:  48%|████▊     | 1908/4000 [00:01<00:01, 1974.09draws/s]
#
# Sampling 4 chains, 0 divergences:  53%|█████▎    | 2105/4000 [00:01<00:00, 1942.64draws/s]
#
# Sampling 4 chains, 0 divergences:  58%|█████▊    | 2303/4000 [00:01<00:00, 1946.43draws/s]
#
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2509/4000 [00:01<00:00, 1978.64draws/s]
#
# Sampling 4 chains, 0 divergences:  68%|██████▊   | 2725/4000 [00:01<00:00, 2029.76draws/s]
#
# Sampling 4 chains, 0 divergences:  73%|███████▎  | 2929/4000 [00:01<00:00, 1974.94draws/s]
#
# Sampling 4 chains, 0 divergences:  78%|███████▊  | 3136/4000 [00:01<00:00, 2000.09draws/s]
#
# Sampling 4 chains, 0 divergences:  84%|████████▍ | 3352/4000 [00:01<00:00, 2043.34draws/s]
#
# Sampling 4 chains, 0 divergences:  89%|████████▉ | 3569/4000 [00:01<00:00, 2076.01draws/s]
# Sampling 4 chains, 0 divergences:  95%|█████████▍| 3785/4000 [00:01<00:00, 2100.08draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1883.19draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#  98%|█████████▊| 246/250 [16:40<00:17,  4.37s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   2%|▏         | 61/4000 [00:00<00:06, 608.51draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▋         | 257/4000 [00:00<00:04, 767.19draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 490/4000 [00:00<00:03, 960.43draws/s]
#
# Sampling 4 chains, 0 divergences:  17%|█▋        | 682/4000 [00:00<00:02, 1129.55draws/s]
#
# Sampling 4 chains, 0 divergences:  22%|██▏       | 891/4000 [00:00<00:02, 1309.31draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1103/4000 [00:00<00:01, 1478.73draws/s]
#
# Sampling 4 chains, 0 divergences:  34%|███▎      | 1345/4000 [00:00<00:01, 1673.20draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1560/4000 [00:00<00:01, 1792.42draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1768/4000 [00:00<00:01, 1866.42draws/s]
#
# Sampling 4 chains, 0 divergences:  49%|████▉     | 1972/4000 [00:01<00:01, 1887.96draws/s]
#
# Sampling 4 chains, 0 divergences:  55%|█████▍    | 2196/4000 [00:01<00:00, 1980.58draws/s]
#
# Sampling 4 chains, 0 divergences:  60%|██████    | 2404/4000 [00:01<00:00, 1959.96draws/s]
#
# Sampling 4 chains, 0 divergences:  66%|██████▌   | 2637/4000 [00:01<00:00, 2057.06draws/s]
#
# Sampling 4 chains, 0 divergences:  72%|███████▏  | 2867/4000 [00:01<00:00, 2123.33draws/s]
#
# Sampling 4 chains, 0 divergences:  78%|███████▊  | 3108/4000 [00:01<00:00, 2197.23draws/s]
#
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3332/4000 [00:01<00:00, 2181.57draws/s]
#
# Sampling 4 chains, 0 divergences:  89%|████████▉ | 3556/4000 [00:01<00:00, 2189.34draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1882.26draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
#  99%|█████████▉| 247/250 [16:44<00:12,  4.24s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|          | 23/4000 [00:00<00:17, 229.70draws/s]
#
# Sampling 4 chains, 0 divergences:   5%|▍         | 183/4000 [00:00<00:12, 309.01draws/s]
#
# Sampling 4 chains, 0 divergences:  11%|█         | 424/4000 [00:00<00:08, 418.44draws/s]
#
# Sampling 4 chains, 0 divergences:  16%|█▋        | 655/4000 [00:00<00:06, 554.65draws/s]
#
# Sampling 4 chains, 0 divergences:  22%|██▏       | 890/4000 [00:00<00:04, 719.46draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1136/4000 [00:00<00:03, 913.28draws/s]
#
# Sampling 4 chains, 0 divergences:  34%|███▍      | 1356/4000 [00:00<00:02, 1107.34draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▉      | 1566/4000 [00:00<00:01, 1290.30draws/s]
#
# Sampling 4 chains, 0 divergences:  45%|████▌     | 1805/4000 [00:00<00:01, 1496.88draws/s]
#
# Sampling 4 chains, 0 divergences:  50%|█████     | 2020/4000 [00:01<00:01, 1646.74draws/s]
#
# Sampling 4 chains, 0 divergences:  57%|█████▋    | 2269/4000 [00:01<00:00, 1832.29draws/s]
#
# Sampling 4 chains, 0 divergences:  63%|██████▎   | 2503/4000 [00:01<00:00, 1958.27draws/s]
#
# Sampling 4 chains, 0 divergences:  69%|██████▊   | 2744/4000 [00:01<00:00, 2073.72draws/s]
#
# Sampling 4 chains, 0 divergences:  75%|███████▍  | 2993/4000 [00:01<00:00, 2180.29draws/s]
#
# Sampling 4 chains, 0 divergences:  81%|████████  | 3230/4000 [00:01<00:00, 2195.01draws/s]
#
# Sampling 4 chains, 0 divergences:  87%|████████▋ | 3470/4000 [00:01<00:00, 2252.33draws/s]
#
# Sampling 4 chains, 0 divergences:  93%|█████████▎| 3705/4000 [00:01<00:00, 1887.74draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1890.99draws/s]
#
#  99%|█████████▉| 248/250 [16:48<00:08,  4.14s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|▏         | 58/4000 [00:00<00:06, 577.10draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▋         | 259/4000 [00:00<00:05, 733.91draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 491/4000 [00:00<00:03, 922.79draws/s]
#
# Sampling 4 chains, 0 divergences:  18%|█▊        | 700/4000 [00:00<00:02, 1107.91draws/s]
#
# Sampling 4 chains, 0 divergences:  23%|██▎       | 901/4000 [00:00<00:02, 1278.89draws/s]
#
# Sampling 4 chains, 0 divergences:  28%|██▊       | 1108/4000 [00:00<00:02, 1444.41draws/s]
#
# Sampling 4 chains, 0 divergences:  33%|███▎      | 1321/4000 [00:00<00:01, 1596.96draws/s]
#
# Sampling 4 chains, 0 divergences:  38%|███▊      | 1524/4000 [00:00<00:01, 1704.06draws/s]
#
# Sampling 4 chains, 0 divergences:  44%|████▍     | 1769/4000 [00:00<00:01, 1874.04draws/s]
#
# Sampling 4 chains, 0 divergences:  50%|████▉     | 1997/4000 [00:01<00:01, 1978.97draws/s]
#
# Sampling 4 chains, 0 divergences:  56%|█████▌    | 2231/4000 [00:01<00:00, 2074.86draws/s]
#
# Sampling 4 chains, 0 divergences:  62%|██████▏   | 2469/4000 [00:01<00:00, 2156.27draws/s]
#
# Sampling 4 chains, 0 divergences:  67%|██████▋   | 2694/4000 [00:01<00:00, 2162.56draws/s]
#
# Sampling 4 chains, 0 divergences:  74%|███████▎  | 2945/4000 [00:01<00:00, 2255.63draws/s]
#
# Sampling 4 chains, 0 divergences:  80%|███████▉  | 3183/4000 [00:01<00:00, 2290.14draws/s]
#
# Sampling 4 chains, 0 divergences:  85%|████████▌ | 3417/4000 [00:01<00:00, 2252.87draws/s]
#
# Sampling 4 chains, 0 divergences:  91%|█████████ | 3646/4000 [00:01<00:00, 2242.91draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1870.67draws/s]
# The number of effective samples is smaller than 25% for some parameters.
#
# 100%|█████████▉| 249/250 [16:52<00:04,  4.08s/it]Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
#
#
# Sampling 4 chains, 0 divergences:   0%|          | 0/4000 [00:00<?, ?draws/s]
#
# Sampling 4 chains, 0 divergences:   1%|▏         | 52/4000 [00:00<00:07, 501.80draws/s]
#
# Sampling 4 chains, 0 divergences:   6%|▌         | 238/4000 [00:00<00:05, 642.20draws/s]
#
# Sampling 4 chains, 0 divergences:  12%|█▏        | 490/4000 [00:00<00:04, 826.84draws/s]
#
# Sampling 4 chains, 0 divergences:  19%|█▉        | 757/4000 [00:00<00:03, 1042.46draws/s]
#
# Sampling 4 chains, 0 divergences:  26%|██▌       | 1022/4000 [00:00<00:02, 1273.70draws/s]
#
# Sampling 4 chains, 0 divergences:  32%|███▏      | 1289/4000 [00:00<00:01, 1508.46draws/s]
#
# Sampling 4 chains, 0 divergences:  39%|███▊      | 1545/4000 [00:00<00:01, 1719.86draws/s]
#
# Sampling 4 chains, 0 divergences:  45%|████▌     | 1809/4000 [00:00<00:01, 1920.07draws/s]
#
# Sampling 4 chains, 0 divergences:  53%|█████▎    | 2110/4000 [00:00<00:00, 2153.57draws/s]
#
# Sampling 4 chains, 0 divergences:  61%|██████    | 2426/4000 [00:01<00:00, 2380.15draws/s]
#
# Sampling 4 chains, 0 divergences:  68%|██████▊   | 2724/4000 [00:01<00:00, 2531.97draws/s]
#
# Sampling 4 chains, 0 divergences:  75%|███████▌  | 3018/4000 [00:01<00:00, 2641.85draws/s]
#
# Sampling 4 chains, 0 divergences:  83%|████████▎ | 3316/4000 [00:01<00:00, 2730.91draws/s]
# Sampling 4 chains, 0 divergences:  90%|█████████ | 3613/4000 [00:01<00:00, 2796.95draws/s]
#
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2285.77draws/s]
#
# 100%|██████████| 250/250 [16:55<00:00,  4.06s/it]

# %%
exp_diff_shuffle_tau_array = np.array([this_trace["tau"] for this_trace in exp_shuffle_diff_traces])
con_diff_shuffle_tau_array = np.array([this_trace["tau"] for this_trace in con_shuffle_diff_traces])
np.save('exp_diff_shuffle_tau_array',exp_diff_shuffle_tau_array)
np.save('con_diff_shuffle_tau_array',con_diff_shuffle_tau_array)
exp_diff_shuffle_tau_hists = np.array([np.histogram(x, bins)[0] for x in exp_diff_shuffle_tau_array])
con_diff_shuffle_tau_hists = np.array([np.histogram(x, bins)[0] for x in con_diff_shuffle_tau_array])

# %%
# fig,ax = plt.subplots(2,2, figsize = (10,5), sharey = 'row')
# ax[0,0].plot(con_diff_shuffle_tau_hists.T);
# ax[0,1].plot(exp_diff_shuffle_tau_hists.T);
# #ax[1,0].hist(con_diff_shuffle_tau_array.T, bins, stacked = 'true');
# #ax[1,1].hist(exp_diff_shuffle_tau_array.T, bins, stacked = 'true');
# ax[0,0].set_title('Control');
# ax[0,1].set_title('Experimental');

# %%
# fig, ax = plt.subplots(1,2, figsize = (7,7))
# ax[0].imshow(zscore(con_diff_shuffle_tau_hists,axis=-1), aspect='auto');
# ax[1].imshow(zscore(exp_diff_shuffle_tau_hists,axis=-1), aspect='auto');

# %%
con_shuffle_hist_array = np.zeros((*con_shuffle_dat.shape[:2],con_diff_shuffle_tau_hists.shape[-1]))
for num, this_ind in enumerate(con_inds):
    con_shuffle_hist_array[tuple(this_ind)] = con_diff_shuffle_tau_hists[num]
exp_shuffle_hist_array = np.zeros((*exp_shuffle_dat.shape[:2],exp_diff_shuffle_tau_hists.shape[-1]))
for num, this_ind in enumerate(exp_inds):
    exp_shuffle_hist_array[tuple(this_ind)] = exp_diff_shuffle_tau_hists[num]

# %%
mean_shuffle_con = np.mean(con_shuffle_hist_array,axis=0)
mean_shuffle_exp = np.mean(exp_shuffle_hist_array,axis=0)
std_shuffle_con = np.std(con_shuffle_hist_array,axis=0)
std_shuffle_exp = np.std(exp_shuffle_hist_array,axis=0)

# %%
fig,ax = plt.subplots(1,2, figsize = (10,5),sharey=True)
x = np.arange(con_shuffle_hist_array.shape[-1])
for mean, std in zip(mean_shuffle_con, std_shuffle_con):
    ax[0].fill_between(x, mean+std, mean-std, alpha = 0.5)
    ax[0].plot(x, mean)
for mean, std in zip(mean_shuffle_exp, std_shuffle_exp):
    ax[1].fill_between(x, mean+std, mean-std, alpha = 0.5)
    ax[1].plot(x, mean)

# %%
# Calculate confidence intervals for each animal, for each timepoint
con_shuffle_hist_array = np.moveaxis(con_shuffle_hist_array,0,-1)
exp_shuffle_hist_array = np.moveaxis(exp_shuffle_hist_array,0,-1)

# %%
## Only looking for values HIGHER than control. NOT INTERESTED in below control

con_cis = np.zeros(con_shuffle_hist_array.shape[:-1], dtype = np.object)
con_cis_sig = np.zeros(con_cis.shape)
alpha = 0.01
wanted_percs = (100*(alpha/2),100*(1-(alpha)/2)) 
for animal_num,animal in enumerate(con_shuffle_hist_array):
    for time_num,time in enumerate(animal):
        ci_bounds = np.percentile(animal.flatten(), wanted_percs)
        con_cis[animal_num,time_num] = ci_bounds
        condition = con_diff_tau_hists[animal_num,time_num] > ci_bounds[1]
        if condition:
            con_cis_sig[animal_num,time_num] = 1

# %%
exp_cis = np.zeros(exp_shuffle_hist_array.shape[:-1], dtype = np.object)
exp_cis_sig = np.zeros(exp_cis.shape)
wanted_percs = (100*(alpha/2),100*(1-(alpha)/2)) 
for animal_num,animal in enumerate(exp_shuffle_hist_array):
    for time_num,time in enumerate(animal):
        ci_bounds = np.percentile(animal.flatten(), wanted_percs)
        exp_cis[animal_num,time_num] = ci_bounds
        expdition = exp_diff_tau_hists[animal_num,time_num] > ci_bounds[1]
        if expdition:
            exp_cis_sig[animal_num,time_num] = 1

# %%
fig,ax = plt.subplots(1,2, figsize = (10,5),sharey=True)
plt.suptitle('Significant deviations from shuffled bounds')
ax[0].imshow(con_cis_sig, aspect = 'auto')
ax[0].set_title('Control')
ax[1].imshow(exp_cis_sig, aspect = 'auto')
ax[1].set_title('Experimental')
# Out:
# Text(0.5, 1.0, 'Experimental')

# %%
mean_vals = []
for animal in exp_cis_sig:
    if sum(animal):
        mean_vals.append(np.mean(bins[np.where(animal)[0]]))

# %%
plt.boxplot(mean_vals);
plt.scatter(np.ones(len(mean_vals))+(np.random.random(len(mean_vals))-0.5)*0.1, mean_vals, s= 100)

# %% [markdown]
# # LFP Diff Mean + Var (3 State)

# %%
# Generate one trace for each dataset
exp_diff_traces = []
for data_vals in exp_diff_lfp:
    with full_model3:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        exp_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Generate one trace for each dataset
con_diff_traces = []
for data_vals in con_diff_lfp:
    with full_model3:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        con_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 45 divergences: 100%|██████████| 4000/4000 [00:07<00:00, 570.36draws/s]
# There were 38 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 97 divergences: 100%|██████████| 4000/4000 [00:07<00:00, 553.10draws/s]
# There were 71 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.25611888174187436, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.33828557423020905, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 10 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6526359029719541, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 296 divergences: 100%|██████████| 4000/4000 [00:05<00:00, 777.22draws/s]
# There were 50 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 15 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7182557234205867, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 198 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.2731015039865254, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 33 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6755614483102558, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.2 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 9 divergences: 100%|██████████| 4000/4000 [00:05<00:00, 788.03draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 11 divergences: 100%|██████████| 4000/4000 [00:04<00:00, 888.11draws/s]
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9112428940226877, but should be close to 0.8. Try to increase the number of tuning steps.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8936357889461484, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 7 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6108346758202647, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 13 divergences: 100%|██████████| 4000/4000 [00:06<00:00, 624.07draws/s]
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 6 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 69 divergences: 100%|██████████| 4000/4000 [00:05<00:00, 681.86draws/s]
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 39 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6375819737462752, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 15 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 27 divergences: 100%|██████████| 4000/4000 [00:07<00:00, 568.54draws/s]
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7049548058187851, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 20 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 35 divergences: 100%|██████████| 4000/4000 [00:07<00:00, 503.96draws/s]
# There were 11 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6781524534787172, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 8 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.7052367912450271, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 13 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 46 divergences: 100%|██████████| 4000/4000 [00:06<00:00, 655.39draws/s]
# There were 22 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 14 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 151 divergences: 100%|██████████| 4000/4000 [00:07<00:00, 519.71draws/s]
# There were 27 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6470198449749521, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 76 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5510902639851388, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 21 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 27 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6609399392123296, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig_3, sig_2, sig_1, mu_3, mu_2, mu_1]
# Sampling 4 chains, 114 divergences: 100%|██████████| 4000/4000 [00:07<00:00, 539.29draws/s]
# There were 21 divergences after tuning. Increase `target_accept` or reparameterize.
# There were 16 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6411861167962698, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 26 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.5309864981049761, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 51 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6631804238525019, but should be close to 0.8. Try to increase the number of tuning steps.
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
exp_diff_tau_array = np.array([this_trace["tau"][:,1] for this_trace in exp_diff_traces])
con_diff_tau_array = np.array([this_trace["tau"][:,1] for this_trace in con_diff_traces])
exp_diff_tau_hists = np.array([np.histogram(x, bins)[0] for x in exp_diff_tau_array])
con_diff_tau_hists = np.array([np.histogram(x, bins)[0] for x in con_diff_tau_array])

# %%
fig,ax = plt.subplots(2,2, figsize = (10,5), sharey = 'row')
ax[0,0].plot(con_diff_tau_hists.T);
ax[0,1].plot(exp_diff_tau_hists.T);
ax[1,0].hist(con_diff_tau_array.T, bins, stacked = 'true');
ax[1,1].hist(exp_diff_tau_array.T, bins, stacked = 'true');
ax[0,0].set_title('Control');
ax[0,1].set_title('Experimental');

# %% [markdown]
# # ==== Rearing ====

# %%
rear_dat = np.array([[np.load(x,'r')[:] for x in group] for group in rear_groups])
zscore_rear_dat = np.array([[zscore(np.load(x,'r')[:],axis=-1) for x in group] for group in rear_groups])
imputer = SimpleImputer(strategy = 'constant', fill_value = 0)
inds = np.ndindex(zscore_rear_dat.shape)
for this_ind in inds:
    zscore_rear_dat[this_ind] = imputer.fit_transform(zscore_rear_dat[this_ind])

# %%
inds = list(np.ndindex(rear_dat.shape))
fig,ax = plt.subplots(2,2,sharex=True, sharey = 'row')
for this_ind in inds:
    ax[this_ind].imshow(rear_dat[this_ind],aspect='auto')
    ax[this_ind].set_title(os.path.basename(rear_groups[this_ind]))
plt.tight_layout()

# %%
exp_diff_rear_raw = np.diff(rear_dat[1], axis=0)[0]
con_diff_rear_raw = np.diff(rear_dat[0], axis=0)[0]

# %%
fig,ax = plt.subplots(1,2, figsize = (15,3))
ax[0].imshow(con_diff_rear_raw,aspect='auto');
ax[1].imshow(exp_diff_rear_raw,aspect='auto');

# %%
fig,ax = plt.subplots(2,1)
ax[0].plot(con_diff_rear_raw.T);
ax[1].plot(exp_diff_rear_raw[1:].T);

# %%
inds = list(np.ndindex(lfp_dat.shape))
fig,ax = plt.subplots(2,2,sharex=True, sharey = 'row')
for this_ind in inds:
    ax[this_ind].imshow(zscore_rear_dat[this_ind],aspect='auto')
    ax[this_ind].set_title(os.path.basename(lfp_groups[this_ind]))
plt.tight_layout()

# %% [markdown]
# ## ==== Diff Changes MEAN MODEL ====

# %%
exp_diff_rear = np.diff(zscore_rear_dat[1], axis=0)[0]
con_diff_rear = np.diff(zscore_rear_dat[0], axis=0)[0]

# %%
fig,ax = plt.subplots(1,2, figsize = (15,3))
ax[0].imshow(con_diff_rear,aspect='auto');
ax[1].imshow(exp_diff_rear,aspect='auto');

# %%
fig,ax = plt.subplots(2,1)
ax[0].plot(con_diff_rear.T);
ax[1].plot(exp_diff_rear[1:].T);

# %%
mean_con_diff_rear = np.mean(con_diff_rear,axis=0)
mean_exp_diff_rear = np.mean(exp_diff_rear,axis=0)
fig,ax = plt.subplots(2,1)
ax[0].plot(mean_con_diff_rear);
ax[1].plot(mean_exp_diff_rear);

# %%
# Generate one trace for each dataset
exp_diff_traces = []
for data_vals in exp_diff_rear:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        exp_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
        
# Generate one trace for each dataset
con_diff_traces = []
for data_vals in con_diff_rear:
    with mean_model:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        con_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2478.47draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2141.25draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2354.76draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2439.26draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1763.31draws/s]
# The acceptance probability does not match the target. It is 0.651558509795371, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2417.32draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2951.49draws/s]
# The acceptance probability does not match the target. It is 0.36424506531125805, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.9215782886703066, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2111.55draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1810.97draws/s]
# The acceptance probability does not match the target. It is 0.881029804776901, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %%
exp_diff_tau_array = np.array([this_trace["tau"] for this_trace in exp_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].hist(exp_diff_tau_array.T, bins, stacked = 'true');
ax[1].hist(exp_diff_tau_array.flatten(), bins, stacked = 'true');

#ax[0,0].set_ylabel('Con');
#ax[1,0].set_ylabel('Exp');

# %%
exp_diff_tau_hists = np.array([np.histogram(x, bins)[0] for x in exp_diff_tau_array])
fig,ax = plt.subplots(2,1, figsize = (5,5))
ax[0].imshow(exp_diff_tau_hists,aspect='auto');
ax[1].plot(exp_diff_tau_hists.T);

# %%
con_diff_tau_array = np.array([this_trace["tau"] for this_trace in con_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(1,2, figsize = (15,5))
ax[0].hist(con_diff_tau_array.T, bins, stacked = 'true');
ax[1].hist(con_diff_tau_array.flatten(), bins, stacked = 'true');

#ax[0,0].set_ylabel('Con');
#ax[1,0].set_ylabel('Exp');

# %%
con_diff_tau_hists = np.array([np.histogram(x, bins)[0] for x in con_diff_tau_array])
fig,ax = plt.subplots(2,1, figsize = (5,5))
ax[0].imshow(con_diff_tau_hists,aspect='auto');
ax[1].plot(con_diff_tau_hists.T);

# %% [markdown]
# ### ===== Comparison =====

# %%
fig,ax = plt.subplots(2,2, figsize = (10,5), sharey = 'row')
ax[0,0].plot(con_diff_tau_hists.T);
ax[0,1].plot(exp_diff_tau_hists.T);
ax[1,0].hist(con_diff_tau_array.T, bins, stacked = 'true');
ax[1,1].hist(exp_diff_tau_array.T, bins, stacked = 'true');
ax[0,0].set_title('Control');
ax[0,1].set_title('Experimental');

# %% [markdown]
# ## ==== Diff Changes 3 State MEAN MODEL ====

# %%
with pm.Model() as mean_model3:
    
    # Define shared "Data" holder to fit same model to different datasets 
    data = pm.Data("data", zscore_lfp_dat[0,0][0])
    # Defining variables with priors
    alpha = data.mean()  # Recall count_data is the
                                   # variable that holds our txt counts
    mu_1 = pm.Normal("mu_1", mu=alpha, sigma = 1, testval = 0)
    mu_2 = pm.Normal("mu_2", mu=alpha, sigma = 1, testval = 0)
    mu_3 = pm.Normal("mu_3", mu=alpha, sigma = 1, testval = 0)
    sigma = pm.HalfCauchy('sig', 1)

    idx = np.arange(np.array(mean_model["data"].get_value()).shape[-1])
    
    # Uniform prior
    tau_latent = pm.Uniform('tau_latent', 0, 1, shape = 2, testval = [0.3,0.6])
    tau_sort = pm.Deterministic('tau_sort', tau_latent.sort())
    
    tau = pm.Deterministic('tau', idx.min() + (idx.max() - idx.min()) * tau_sort)
    
    
    # Using sigmoid rather than switch is supposed to be better
    # for sampler
    weight1 = tt.nnet.sigmoid(2 * (idx - tau[0]))
    weight2 = tt.nnet.sigmoid(2 * (idx - tau[1]))
    mu_ = (1 - weight1) * mu_1 + (weight1*(1-weight2)) * mu_2 + weight2 * mu_3

    observation = pm.Normal("obs", mu=mu_, sigma = sigma, observed=data)

pm.model_to_graphviz(mean_model3)

# %%
# Generate one trace for each dataset
exp_diff_traces = []
for data_vals in exp_diff_rear:
    with mean_model3:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        exp_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
        
# Generate one trace for each dataset
con_diff_traces = []
for data_vals in con_diff_rear:
    with mean_model3:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        con_diff_traces.append(pm.sample())#pm.sample(step = pm.Metropolis()))
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:02<00:00, 1363.04draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:04<00:00, 981.50draws/s]
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:03<00:00, 1204.39draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:03<00:00, 1201.91draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:05<00:00, 798.38draws/s]
# The acceptance probability does not match the target. It is 0.6989960156816493, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:03<00:00, 1222.70draws/s]
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:04<00:00, 812.79draws/s]
# The acceptance probability does not match the target. It is 0.699485612444129, but should be close to 0.8. Try to increase the number of tuning steps.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:03<00:00, 1000.45draws/s]
# The acceptance probability does not match the target. It is 0.7045265858444781, but should be close to 0.8. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.702153730990538, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [tau_latent, sig, mu_3, mu_2, mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:04<00:00, 931.99draws/s]
# The number of effective samples is smaller than 25% for some parameters.

# %%
#pm.traceplot(exp_diff_traces[0]);

# %%
exp_diff_tau_array = np.array([this_trace["tau"] for this_trace in exp_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].hist(exp_diff_tau_array[...,0].T, bins, stacked = 'true');
ax[0,1].hist(exp_diff_tau_array[...,0].flatten(), bins, stacked = 'true');
ax[1,0].hist(exp_diff_tau_array[...,1].T, bins, stacked = 'true');
ax[1,1].hist(exp_diff_tau_array[...,1].flatten(), bins, stacked = 'true');

# %%
exp_diff_tau_hists = np.array([[np.histogram(x, bins)[0] for x in exp_diff_tau_array[...,this_tau]] for this_tau in range(2)])
fig,ax = plt.subplots(2,2, figsize = (10,5))
ax[0,0].imshow(exp_diff_tau_hists[0],aspect='auto');
ax[0,1].plot(exp_diff_tau_hists[0].T);
ax[1,0].imshow(exp_diff_tau_hists[1],aspect='auto');
ax[1,1].plot(exp_diff_tau_hists[1].T);

# %%
con_diff_tau_array = np.array([this_trace["tau"] for this_trace in con_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].hist(con_diff_tau_array[...,0].T, bins, stacked = 'true');
ax[0,1].hist(con_diff_tau_array[...,0].flatten(), bins, stacked = 'true');
ax[1,0].hist(con_diff_tau_array[...,1].T, bins, stacked = 'true');
ax[1,1].hist(con_diff_tau_array[...,1].flatten(), bins, stacked = 'true');

# %%
con_diff_tau_hists = np.array([[np.histogram(x, bins)[0] for x in con_diff_tau_array[...,this_tau]] for this_tau in range(2)])
fig,ax = plt.subplots(2,2, figsize = (10,5))
ax[0,0].imshow(con_diff_tau_hists[0],aspect='auto');
ax[0,1].plot(con_diff_tau_hists[0].T);
ax[1,0].imshow(con_diff_tau_hists[1],aspect='auto');
ax[1,1].plot(con_diff_tau_hists[1].T);

# %% [markdown]
# ## Group Changepoint comparison

# %%
fig,ax = plt.subplots(2,2, figsize = (10,5), sharey = 'col')
ax[0,0].set_ylabel('Control')
ax[1,0].set_ylabel('Experimental')
ax[0,0].set_title('Change1')
ax[0,1].set_title('Change2')
ax[0,0].plot(con_diff_tau_hists[0].T);
ax[0,1].plot(con_diff_tau_hists[1].T);
ax[1,0].plot(exp_diff_tau_hists[0].T);
ax[1,1].plot(exp_diff_tau_hists[1].T);

# %% [markdown]
# ## ==== Diff Changes 3 State FULL MODEL ====

# %%
# Generate one trace for each dataset
exp_diff_traces = []
for data_vals in exp_diff_rear:
    with full_model3:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        exp_diff_traces.append(pm.sample(step = pm.Metropolis()))
        
# Generate one trace for each dataset
con_diff_traces = []
for data_vals in con_diff_rear:
    with full_model3:
        # Switch out the observed dataset
        pm.set_data({"data": data_vals})
        con_diff_traces.append(pm.sample(step = pm.Metropolis()))
# Out:
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2565.87draws/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2567.24draws/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2628.74draws/s]
# The rhat statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2507.14draws/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2487.40draws/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2525.92draws/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2572.10draws/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2625.31draws/s]
# The rhat statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Multiprocess sampling (4 chains in 4 jobs)
# CompoundStep
# >Metropolis: [tau_latent]
# >Metropolis: [sig_3]
# >Metropolis: [sig_2]
# >Metropolis: [sig_1]
# >Metropolis: [mu_3]
# >Metropolis: [mu_2]
# >Metropolis: [mu_1]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 2665.98draws/s]
# The rhat statistic is larger than 1.2 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
test_tau = exp_diff_traces[2]['tau']
plt.scatter(test_tau[:,0],test_tau[:,1])

# %%
exp_diff_tau_array = np.array([this_trace["tau"] for this_trace in exp_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].hist(exp_diff_tau_array[...,0].T, bins, stacked = 'true');
ax[0,1].hist(exp_diff_tau_array[...,0].flatten(), bins, stacked = 'true');
ax[1,0].hist(exp_diff_tau_array[...,1].T, bins, stacked = 'true');
ax[1,1].hist(exp_diff_tau_array[...,1].flatten(), bins, stacked = 'true');

# %%
exp_diff_tau_hists = np.array([[np.histogram(x, bins)[0] for x in exp_diff_tau_array[...,this_tau]] for this_tau in range(2)])
fig,ax = plt.subplots(2,2, figsize = (10,5))
ax[0,0].imshow(exp_diff_tau_hists[0],aspect='auto');
ax[0,1].plot(exp_diff_tau_hists[0].T);
ax[1,0].imshow(exp_diff_tau_hists[1],aspect='auto');
ax[1,1].plot(exp_diff_tau_hists[1].T);

# %%
con_diff_tau_array = np.array([this_trace["tau"] for this_trace in con_diff_traces])

bins = np.linspace(0,20,100)
fig, ax = plt.subplots(2,2, figsize = (15,5))
ax[0,0].hist(con_diff_tau_array[...,0].T, bins, stacked = 'true');
ax[0,1].hist(con_diff_tau_array[...,0].flatten(), bins, stacked = 'true');
ax[1,0].hist(con_diff_tau_array[...,1].T, bins, stacked = 'true');
ax[1,1].hist(con_diff_tau_array[...,1].flatten(), bins, stacked = 'true');

# %%
con_diff_tau_hists = np.array([[np.histogram(x, bins)[0] for x in con_diff_tau_array[...,this_tau]] for this_tau in range(2)])
fig,ax = plt.subplots(2,2, figsize = (10,5))
ax[0,0].imshow(con_diff_tau_hists[0],aspect='auto');
ax[0,1].plot(con_diff_tau_hists[0].T);
ax[1,0].imshow(con_diff_tau_hists[1],aspect='auto');
ax[1,1].plot(con_diff_tau_hists[1].T);

# %% [markdown]
# ## Group Changepoint comparison

# %%
fig,ax = plt.subplots(2,2, figsize = (10,5), sharey = 'col')
ax[0,0].set_ylabel('Control')
ax[1,0].set_ylabel('Experimental')
ax[0,0].set_title('Change1')
ax[0,1].set_title('Change2')
ax[0,0].plot(con_diff_tau_hists[0].T);
ax[0,1].plot(con_diff_tau_hists[1].T);
ax[1,0].plot(exp_diff_tau_hists[0].T);
ax[1,1].plot(exp_diff_tau_hists[1].T);
