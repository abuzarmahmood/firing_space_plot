# %%
# Import stuff
import os
import scipy
import scipy.stats as stats
import pymc3 as pm
import theano.tensor as tt
import theano

# %matplotlib inline
from IPython.core.pylabtools import figsize
import numpy as np
from matplotlib import pyplot as plt
figsize(11, 9)

# %%
with pm.Model() as model:
    test = pm.Normal('test', 0 , 1, shape = (10,3))

# %%
pm.model_to_graphviz(model)

# %%
with model:
    samples = pm.sample()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [test]
# Sampling 4 chains, 0 divergences: 100%|██████████| 4000/4000 [00:01<00:00, 3589.30draws/s]

# %%
pm.traceplot(samples);
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f85b2397ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f85b1bccb38>]],
#       dtype=object)
