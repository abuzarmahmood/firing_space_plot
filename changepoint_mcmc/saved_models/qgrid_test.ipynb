# %%
import numpy as np
import pandas as pd
import qgrid

# %%
df = pd.read_csv('model_database.csv', index_col = 0)
qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
qgrid_widget
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': True, 'defau…

# %%
x = qgrid_widget.get_changed_df()

# %%
x
# Out:
#     preprocess.time_lims  preprocess.bin_width preprocess.data_transform  \
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
# 0.0         [2000, 4000]                    50                       NaN
#
#     preprocess.preprocessor_name  model.states  model.fit  model.samples  \
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
# 0.0      preprocess_single_taste             2      40000          20000
# 0.0      preprocess_single_taste             3      40000          20000
# 0.0      preprocess_single_taste             4      40000          20000
#
#     model.model_template_name model.inference_func_name  \
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
# 0.0      single_taste_poisson                  advi_fit
#
#                                          data.data_dir  \
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
# 0.0  /media/bigdata/Abuzar_Data/bla_gc/AM11/AM11_4T...
#
#                        data.basename data.animal_name data.session_date  \
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0  AM11_4Tastes_191030_114043_copy             AM11              copy
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191031_083633             AM11            083633
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191101_084921             AM11            084921
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
# 0.0       AM11_4Tastes_191029_171714             AM11            171714
#
#      data.taste_num data.region_name       exp.exp_name exp.model_id  \
# 0.0               0              bla  pretty_bla_change     98dd75a3
# 0.0               0              bla  pretty_bla_change     6bf00370
# 0.0               0              bla  pretty_bla_change     c2972913
# 0.0               1              bla  pretty_bla_change     96b37895
# 0.0               1              bla  pretty_bla_change     a7c80296
# 0.0               1              bla  pretty_bla_change     871bb30e
# 0.0               2              bla  pretty_bla_change     af46db7a
# 0.0               2              bla  pretty_bla_change     58bcbcd8
# 0.0               2              bla  pretty_bla_change     b82838cb
# 0.0               3              bla  pretty_bla_change     6ef910e9
# 0.0               3              bla  pretty_bla_change     d73034d6
# 0.0               3              bla  pretty_bla_change     d24f8220
# 0.0               0              bla  pretty_bla_change     d18f7d99
# 0.0               0              bla  pretty_bla_change     9e6721b8
# 0.0               0              bla  pretty_bla_change     764d167d
# 0.0               1              bla  pretty_bla_change     205a3502
# 0.0               1              bla  pretty_bla_change     28b41253
# 0.0               1              bla  pretty_bla_change     b6621dc6
# 0.0               2              bla  pretty_bla_change     5012d7ec
# 0.0               2              bla  pretty_bla_change     e48a516a
# 0.0               2              bla  pretty_bla_change     2674cc07
# 0.0               3              bla  pretty_bla_change     01f135ed
# 0.0               3              bla  pretty_bla_change     db786ce7
# 0.0               3              bla  pretty_bla_change     26713cd4
# 0.0               0              bla  pretty_bla_change     4414d228
# 0.0               0              bla  pretty_bla_change     dd41fcac
# 0.0               0              bla  pretty_bla_change     1682c228
# 0.0               1              bla  pretty_bla_change     f2946840
# 0.0               1              bla  pretty_bla_change     d7e4959e
# 0.0               1              bla  pretty_bla_change     72d249da
# 0.0               2              bla  pretty_bla_change     d43df631
# 0.0               2              bla  pretty_bla_change     b6b8f040
# 0.0               2              bla  pretty_bla_change     495dc57a
# 0.0               3              bla  pretty_bla_change     b8263263
# 0.0               3              bla  pretty_bla_change     60a10037
# 0.0               3              bla  pretty_bla_change     b52be0be
# 0.0               0              bla  pretty_bla_change     1f65a80f
# 0.0               0              bla  pretty_bla_change     b1602c8c
# 0.0               0              bla  pretty_bla_change     88fe6a91
# 0.0               1              bla  pretty_bla_change     57fb08f9
# 0.0               1              bla  pretty_bla_change     a73e5220
# 0.0               1              bla  pretty_bla_change     58c66b27
# 0.0               2              bla  pretty_bla_change     ab600f46
# 0.0               2              bla  pretty_bla_change     bae25540
# 0.0               2              bla  pretty_bla_change     b434d276
# 0.0               3              bla  pretty_bla_change     20e6e88a
# 0.0               3              bla  pretty_bla_change     7fbb54e7
# 0.0               3              bla  pretty_bla_change     db64af71
#
#                                          exp.save_path exp.fit_date
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
# 0.0  /media/bigdata/firing_space_plot/changepoint_m...     12-07-21
